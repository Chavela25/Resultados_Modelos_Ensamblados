# %% [markdown]
# # **IMPORTAR BIBLIOTECAS NECESARIAS Y CARGAR DATOS**

# %%
# BIBLIOTECAS NECESARIAS

# Bibliotecas para operaciones numéricas y manejo de datos
import numpy as np  # Operaciones numéricas
import pandas as pd  # Manejo de datos en formato tabular

# División del conjunto de datos y validación cruzada
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

# Modelos de clasificación
import xgboost as xgb

# Importar todo el módulo de métricas
import sklearn.metrics

# Métricas de evaluación y reportes
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    PrecisionRecallDisplay,
    roc_curve, auc,
    classification_report,
    accuracy_score, precision_score, recall_score, f1_score
)

# Bibliotecas para gráficos
import matplotlib.pyplot as plt  # Gráficos básicos
import seaborn as sns  # Gráficos estadísticos, con menos código que matplotlib
import plotly.express as px  # Gráficos interactivos con interfaz sencilla y de alto nivel
import plotly.graph_objects as go  # Gráficos interactivos con interfaz más detallada y de bajo nivel

# Herramientas para iteradores
import itertools  # Herramientas funcionales para crear y utilizar iteradores

# Herramientas para preprocesamiento de datos y evaluación de modelos
from sklearn.preprocessing import StandardScaler  # Escalado de características para normalizar datos
from sklearn.model_selection import learning_curve  # Generación de curvas de aprendizaje para evaluar el rendimiento del modelo
from sklearn.model_selection import validation_curve  # Generación de curvas de validación para evaluar el rendimiento del modelo

# %%
# Cargar el dataset desde un archivo CSV
credit_card = pd.read_csv('C:\\Users\\mmene\\OneDrive\\Escritorio\\TESIS\\BD2\\default_of_credit_card_clients.csv', sep=';')

# %%
credit_card.head(10)
# Out:
#        X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...     X15     X16     X17  \
# 0   20000   2   2   1  24   2   2  -1  -1   -2  ...       0       0       0
# 1  120000   2   2   2  26  -1   2   0   0    0  ...    3272    3455    3261
# 2   90000   2   2   2  34   0   0   0   0    0  ...   14331   14948   15549
# 3   50000   2   2   1  37   0   0   0   0    0  ...   28314   28959   29547
# 4   50000   1   2   1  57  -1   0  -1   0    0  ...   20940   19146   19131
# 5   50000   1   1   2  37   0   0   0   0    0  ...   19394   19619   20024
# 6  500000   1   1   2  29   0   0   0   0    0  ...  542653  483003  473944
# 7  100000   2   2   2  23   0  -1  -1   0    0  ...     221    -159     567
# 8  140000   2   3   1  28   0   0   2   0    0  ...   12211   11793    3719
# 9   20000   1   3   2  35  -2  -2  -2  -2   -1  ...       0   13007   13912
#
#      X18    X19    X20    X21    X22    X23  Y
# 0      0    689      0      0      0      0  1
# 1      0   1000   1000   1000      0   2000  1
# 2   1518   1500   1000   1000   1000   5000  0
# 3   2000   2019   1200   1100   1069   1000  0
# 4   2000  36681  10000   9000    689    679  0
# 5   2500   1815    657   1000   1000    800  0
# 6  55000  40000  38000  20239  13750  13770  0
# 7    380    601      0    581   1687   1542  0
# 8   3329      0    432   1000   1000   1000  0
# 9      0      0      0  13007   1122      0  0
#
# [10 rows x 24 columns]

# %% [markdown]
# # **NORMALIZACIÓN**

# %%
# Paso 1: Separar características (X) y la columna objetivo (y)
X = credit_card.drop(['Y'], axis=1)  # Eliminar la columna 'Y'
y = credit_card['Y']  # Conservar la columna 'Y'

# Paso 2: Crear un objeto StandardScaler
scaler = StandardScaler()

# Paso 3: Ajustar el escalador a las características y transformarlas
scaled = scaler.fit_transform(X)

# Paso 4: Convertir X_scaled de vuelta a un DataFrame
X_scaled = pd.DataFrame(scaled, columns=X.columns)

# Paso 5: Reunir X_scaled con la columna 'Class'
credit_card_scaled = pd.concat([X_scaled, y.reset_index(drop=True)], axis=1)

# Paso 6: Mostrar las primeras filas del DataFrame transformado
credit_card_scaled.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -1.136720  0.810161  0.185828 -1.057295 -1.246020  1.794564  1.782348
# 1 -0.365981  0.810161  0.185828  0.858557 -1.029047 -0.874991  1.782348
# 2 -0.597202  0.810161  0.185828  0.858557 -0.161156  0.014861  0.111736
# 3 -0.905498  0.810161  0.185828 -1.057295  0.164303  0.014861  0.111736
# 4 -0.905498 -1.234323  0.185828 -1.057295  2.334029 -0.874991  0.111736
#
#          X8        X9       X10  ...       X15       X16       X17       X18  \
# 0 -0.696663 -0.666599 -1.530046  ... -0.672497 -0.663059 -0.652724 -0.341942
# 1  0.138865  0.188746  0.234917  ... -0.621636 -0.606229 -0.597966 -0.341942
# 2  0.138865  0.188746  0.234917  ... -0.449730 -0.417188 -0.391630 -0.250292
# 3  0.138865  0.188746  0.234917  ... -0.232373 -0.186729 -0.156579 -0.221191
# 4 -0.696663  0.188746  0.234917  ... -0.346997 -0.348137 -0.331482 -0.221191
#
#         X19       X20       X21       X22       X23  Y
# 0 -0.227086 -0.296801 -0.308063 -0.314136 -0.293382  1
# 1 -0.213588 -0.240005 -0.244230 -0.314136 -0.180878  1
# 2 -0.191887 -0.240005 -0.244230 -0.248683 -0.012122  0
# 3 -0.169361 -0.228645 -0.237846 -0.244166 -0.237130  0
# 4  1.335034  0.271165  0.266434 -0.269039 -0.255187  0
#
# [5 rows x 24 columns]

# %%
credit_card_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      30000 non-null  float64
#  1   X2      30000 non-null  float64
#  2   X3      30000 non-null  float64
#  3   X4      30000 non-null  float64
#  4   X5      30000 non-null  float64
#  5   X6      30000 non-null  float64
#  6   X7      30000 non-null  float64
#  7   X8      30000 non-null  float64
#  8   X9      30000 non-null  float64
#  9   X10     30000 non-null  float64
#  10  X11     30000 non-null  float64
#  11  X12     30000 non-null  float64
#  12  X13     30000 non-null  float64
#  13  X14     30000 non-null  float64
#  14  X15     30000 non-null  float64
#  15  X16     30000 non-null  float64
#  16  X17     30000 non-null  float64
#  17  X18     30000 non-null  float64
#  18  X19     30000 non-null  float64
#  19  X20     30000 non-null  float64
#  20  X21     30000 non-null  float64
#  21  X22     30000 non-null  float64
#  22  X23     30000 non-null  float64
#  23  Y       30000 non-null  int64
# dtypes: float64(23), int64(1)
# memory usage: 5.5 MB

# %%
# VALORES ÚNICOS DE LA COLUMNA 'Class'
# 1. Crea un conjunto de los valores únicos presentes en la columna 'Class' del DataFrame
# 2. Muestra los valores únicos

value_etq = set(credit_card_scaled['Y'])
print("\033[1mVARIABLE RESPUESTA:\033[0m")
print("\nToma el valor de \033[1m1\033[0m en caso de \033[1mIMPAGO\033[0m y toma el valor de \033[1m0\033[0m (SI PAGÓ)\nen \033[1mcaso contrario\033[0m\n")
print(f'Clases: {value_etq}')

credit_card_scaled['Y'].value_counts()
# Out:
# VARIABLE RESPUESTA:
#
# Toma el valor de 1 en caso de IMPAGO y toma el valor de 0 (SI PAGÓ)
# en caso contrario
#
# Clases: {0, 1}
# Y
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %% [markdown]
# # **MODELO XGBoost**

# %%
# 'HOLDOUT METHOD' para evaluar el rendimiento de un modelo de aprendizaje automático
# Este método divide el conjunto de datos en entrenamiento y prueba con diferentes tamaños de entrenamiento
# para evaluar cómo el rendimiento del modelo varía con el tamaño del conjunto de entrenamiento.

# Definir los diferentes tamaños para el conjunto de entrenamiento
train_sizes = [0.75,0.80,0.90]

# Crear una lista para almacenar los resultados de los diferentes conjuntos de entrenamiento y prueba
split_results = []

# Para cada tamaño de entrenamiento en train_sizes
for splits in train_sizes:
  # Se divide los datos X e y en conjuntos de entrenamiento y prueba con el tamaño especificado
  X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, train_size=splits, random_state=42)
  split_results.append((X_train, X_test, y_train, y_test))

# Mostrar las dimensiones de los conjuntos de entrenamiento y prueba para cada tamaño de entrenamiento
for i, (X_train, X_test, y_train, y_test) in enumerate(split_results):
  print(f"\033[1mConjunto con train_size={train_sizes[i]}\033[0m")
  print(f"Dimensión total es: {credit_card_scaled.shape}")
  print(f"X_train dimensión: {X_train.shape}, X_test dimensión: {X_test.shape}")
  print(f"y_train dimensión: {y_train.shape}, y_test dimensión: {y_test.shape}")
  print()
# Out:
# Conjunto con train_size=0.75
# Dimensión total es: (30000, 24)
# X_train dimensión: (22500, 23), X_test dimensión: (7500, 23)
# y_train dimensión: (22500,), y_test dimensión: (7500,)
#
# Conjunto con train_size=0.8
# Dimensión total es: (30000, 24)
# X_train dimensión: (24000, 23), X_test dimensión: (6000, 23)
# y_train dimensión: (24000,), y_test dimensión: (6000,)
#
# Conjunto con train_size=0.9
# Dimensión total es: (30000, 24)
# X_train dimensión: (27000, 23), X_test dimensión: (3000, 23)
# y_train dimensión: (27000,), y_test dimensión: (3000,)

# %%
# MODELO XGBoost

# Lista para almacenar el resultado del modelo para cada conjunto de entrenamiento/prueba
models_split_results = []

# Iterar sobre los conjuntos generados
for i, (X_train, X_test, y_train, y_test) in enumerate(split_results):

  # Definir las métricas de evaluación
  scores = ["precision", "recall", "roc_auc", "f1", "average_precision"]

  # Mostrar información sobre el conjunto actual
  print(f"\033[1mConjunto con train_size={train_sizes[i]}:\033[0m")

  # Crear el modelo XGBoost

  modelo_xgb = xgb.XGBClassifier(random_state=42, objective='binary:logistic')

  # Definir los parámetros para GridSearchCV
  grid_search = {
      "n_estimators": [10,20,50,100,200,500], # Número de árboles en el bosque aleatorio
      "max_depth": [3,4,7,9], # Profundidad máxima de cada
      "learning_rate": [0.02,0.15,0.2,0.4,0.5],
      "gamma": [0,0.25,0.5],
      "lambda": [0,0.25,0.5],
      "alpha": [0,0.25,0.5],
      "booster": ["gbtree"]
      }

  # Medir tiempo de ejecución
  start = pd.Timestamp.now()

  # Configuración de GridSearchCV
  grid = GridSearchCV(
      modelo_xgb,
      grid_search,
      cv=3, # Número de particiones en la validación cruzada
      refit=False, # No volver a entrenar el mejor modelo encontrado en toda la búsqueda
      scoring=scores, # Métricas de evaluación a usar
      verbose = 3, # Mostrar información adicional durante la búsqueda
      return_train_score=True # Devolver los resultados de entrenamiento
      )

  # Ejecutar GridSearchCV para encontrar el mejor modelo
  model_grid = grid.fit(X_train, y_train)

  # Medir tiempo de ejecución de GridSearchCV
  end = pd.Timestamp.now()
  print(f"Duración búsqueda: {end-start}")

  # Almacenar los resultados en la list 'models_split_results'
  models_split_results.append(model_grid.cv_results_)

  # Guardar modelos en un DataFrame
modelos_GSCV1= pd.DataFrame(models_split_results)

model_75 = models_split_results[0]
model_80 = models_split_results[1]
model_90 = models_split_results[2]

#75
# Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
ajuste_modelo_75 = []

# Recorre cada índice 'i' basado en la longitud de los tiempos medios de ajuste ('mean_fit_time')
for i in range(len(model_75['mean_fit_time'])):
  # Crea un diccionario 'execution' para la ejecución actual, extrayendo el valor correspondiente al índice 'i' de cada clave en 'resultados_modelo_75'
  execution = {key: value[i] for key, value in model_75.items()}
  # Añade el diccionario de resultados de la ejecución actual a la lista 'ajuste_modelo_80'
  ajuste_modelo_75.append(execution)

# Convierte la lista de diccionarios 'ajuste_modelo_75' en un DataFrame de pandas para facilitar su manipulación y análisis
modelos_75 = pd.DataFrame(ajuste_modelo_75)
# Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
modelos_75.to_excel('C:\\Users\\mmene\\OneDrive\\Escritorio\\TESIS\\XGBoost\\PRUEBA_RESULTADO\\modelos_75.xlsx')

#80
# Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
ajuste_modelo_80 = []

# Recorre cada índice 'i' basado en la longitud de los tiempos medios de ajuste ('mean_fit_time')
for i in range(len(model_80['mean_fit_time'])):
  # Crea un diccionario 'execution' para la ejecución actual, extrayendo el valor correspondiente al índice 'i' de cada clave en 'resultados_modelo_75'
  execution = {key: value[i] for key, value in model_80.items()}
  # Añade el diccionario de resultados de la ejecución actual a la lista 'ajuste_modelo_80'
  ajuste_modelo_80.append(execution)

# Convierte la lista de diccionarios 'ajuste_modelo_80' en un DataFrame de pandas para facilitar su manipulación y análisis
modelos_80 = pd.DataFrame(ajuste_modelo_80)
# Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
modelos_80.to_excel('C:\\Users\\mmene\\OneDrive\\Escritorio\\TESIS\\XGBoost\\PRUEBA_RESULTADO\\modelos_80.xlsx')


#90
# Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
ajuste_modelo_90 = []

# Recorre cada índice 'i' basado en la longitud de los tiempos medios de ajuste ('mean_fit_time')
for i in range(len(model_90['mean_fit_time'])):
  # Crea un diccionario 'execution' para la ejecución actual, extrayendo el valor correspondiente al índice 'i' de cada clave en 'resultados_modelo_75'
  execution = {key: value[i] for key, value in model_90.items()}
  # Añade el diccionario de resultados de la ejecución actual a la lista 'ajuste_modelo_80'
  ajuste_modelo_90.append(execution)

# Convierte la lista de diccionarios 'ajuste_modelo_90' en un DataFrame de pandas para facilitar su manipulación y análisis
modelos_90 = pd.DataFrame(ajuste_modelo_90)
# Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
modelos_90.to_excel('C:\\Users\\mmene\\OneDrive\\Escritorio\\TESIS\\XGBoost\\PRUEBA_RESULTADO\\modelos_90.xlsx')
# Out:
# Conjunto con train_size=0.75:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.703, test=0.570) f1: (train=0.551, test=0.471) precision: (train=0.807, test=0.700) recall: (train=0.419, test=0.355) roc_auc: (train=0.858, test=0.782) total time=   0.3s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.715, test=0.549) f1: (train=0.546, test=0.430) precision: (train=0.836, test=0.689) recall: (train=0.406, test=0.313) roc_auc: (train=0.864, test=0.778) total time=   0.3s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.712, test=0.537) f1: (train=0.552, test=0.457) precision: (train=0.808, test=0.664) recall: (train=0.419, test=0.348) roc_auc: (train=0.858, test=0.769) total time=   0.2s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.820, test=0.564) f1: (train=0.632, test=0.464) precision: (train=0.893, test=0.690) recall: (train=0.489, test=0.350) roc_auc: (train=0.922, test=0.777) total time=   0.5s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.826, test=0.542) f1: (train=0.638, test=0.429) precision: (train=0.931, test=0.692) recall: (train=0.485, test=0.311) roc_auc: (train=0.921, test=0.773) total time=   0.5s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.825, test=0.533) f1: (train=0.645, test=0.454) precision: (train=0.902, test=0.663) recall: (train=0.501, test=0.346) roc_auc: (train=0.922, test=0.765) total time=   0.5s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.698, test=0.572) f1: (train=0.543, test=0.469) precision: (train=0.800, test=0.707) recall: (train=0.410, test=0.351) roc_auc: (train=0.856, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.710, test=0.550) f1: (train=0.548, test=0.433) precision: (train=0.834, test=0.704) recall: (train=0.408, test=0.313) roc_auc: (train=0.860, test=0.779) total time=   0.2s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.707, test=0.539) f1: (train=0.550, test=0.457) precision: (train=0.808, test=0.667) recall: (train=0.417, test=0.347) roc_auc: (train=0.856, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.812, test=0.566) f1: (train=0.626, test=0.461) precision: (train=0.888, test=0.693) recall: (train=0.484, test=0.345) roc_auc: (train=0.918, test=0.777) total time=   0.5s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.826, test=0.544) f1: (train=0.631, test=0.424) precision: (train=0.919, test=0.689) recall: (train=0.481, test=0.306) roc_auc: (train=0.923, test=0.773) total time=   0.5s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.816, test=0.536) f1: (train=0.634, test=0.446) precision: (train=0.895, test=0.657) recall: (train=0.491, test=0.338) roc_auc: (train=0.917, test=0.767) total time=   0.5s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.694, test=0.574) f1: (train=0.541, test=0.466) precision: (train=0.798, test=0.708) recall: (train=0.409, test=0.348) roc_auc: (train=0.855, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.707, test=0.552) f1: (train=0.543, test=0.430) precision: (train=0.827, test=0.698) recall: (train=0.404, test=0.310) roc_auc: (train=0.859, test=0.779) total time=   0.2s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.703, test=0.542) f1: (train=0.545, test=0.454) precision: (train=0.803, test=0.665) recall: (train=0.413, test=0.345) roc_auc: (train=0.854, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.807, test=0.570) f1: (train=0.625, test=0.460) precision: (train=0.883, test=0.698) recall: (train=0.484, test=0.343) roc_auc: (train=0.917, test=0.778) total time=   0.5s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.820, test=0.543) f1: (train=0.624, test=0.426) precision: (train=0.907, test=0.688) recall: (train=0.475, test=0.309) roc_auc: (train=0.922, test=0.773) total time=   0.6s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.809, test=0.536) f1: (train=0.626, test=0.448) precision: (train=0.886, test=0.657) recall: (train=0.485, test=0.340) roc_auc: (train=0.913, test=0.767) total time=   0.5s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.703, test=0.570) f1: (train=0.552, test=0.470) precision: (train=0.809, test=0.701) recall: (train=0.419, test=0.354) roc_auc: (train=0.858, test=0.782) total time=   0.2s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.715, test=0.550) f1: (train=0.547, test=0.431) precision: (train=0.836, test=0.692) recall: (train=0.407, test=0.313) roc_auc: (train=0.864, test=0.778) total time=   0.2s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.710, test=0.535) f1: (train=0.550, test=0.455) precision: (train=0.808, test=0.667) recall: (train=0.417, test=0.345) roc_auc: (train=0.856, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.818, test=0.565) f1: (train=0.632, test=0.465) precision: (train=0.891, test=0.686) recall: (train=0.490, test=0.351) roc_auc: (train=0.921, test=0.777) total time=   0.5s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.825, test=0.541) f1: (train=0.636, test=0.428) precision: (train=0.931, test=0.692) recall: (train=0.482, test=0.310) roc_auc: (train=0.922, test=0.773) total time=   0.5s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.826, test=0.531) f1: (train=0.642, test=0.454) precision: (train=0.900, test=0.662) recall: (train=0.499, test=0.346) roc_auc: (train=0.922, test=0.765) total time=   0.5s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.698, test=0.572) f1: (train=0.542, test=0.470) precision: (train=0.798, test=0.710) recall: (train=0.410, test=0.352) roc_auc: (train=0.856, test=0.782) total time=   0.2s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.710, test=0.550) f1: (train=0.546, test=0.430) precision: (train=0.833, test=0.699) recall: (train=0.406, test=0.311) roc_auc: (train=0.861, test=0.779) total time=   0.2s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.707, test=0.538) f1: (train=0.551, test=0.458) precision: (train=0.808, test=0.667) recall: (train=0.418, test=0.349) roc_auc: (train=0.856, test=0.769) total time=   0.2s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.811, test=0.569) f1: (train=0.628, test=0.459) precision: (train=0.891, test=0.695) recall: (train=0.485, test=0.342) roc_auc: (train=0.918, test=0.778) total time=   0.5s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.825, test=0.542) f1: (train=0.633, test=0.427) precision: (train=0.916, test=0.686) recall: (train=0.483, test=0.310) roc_auc: (train=0.924, test=0.772) total time=   0.5s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.815, test=0.535) f1: (train=0.630, test=0.449) precision: (train=0.891, test=0.657) recall: (train=0.487, test=0.341) roc_auc: (train=0.917, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.694, test=0.574) f1: (train=0.540, test=0.463) precision: (train=0.797, test=0.705) recall: (train=0.408, test=0.345) roc_auc: (train=0.854, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.707, test=0.551) f1: (train=0.544, test=0.432) precision: (train=0.828, test=0.699) recall: (train=0.405, test=0.313) roc_auc: (train=0.859, test=0.777) total time=   0.2s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.703, test=0.542) f1: (train=0.545, test=0.455) precision: (train=0.803, test=0.665) recall: (train=0.413, test=0.346) roc_auc: (train=0.854, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.805, test=0.569) f1: (train=0.626, test=0.460) precision: (train=0.884, test=0.701) recall: (train=0.484, test=0.342) roc_auc: (train=0.917, test=0.777) total time=   0.5s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.820, test=0.543) f1: (train=0.625, test=0.430) precision: (train=0.907, test=0.686) recall: (train=0.476, test=0.313) roc_auc: (train=0.922, test=0.772) total time=   0.6s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.807, test=0.538) f1: (train=0.628, test=0.449) precision: (train=0.884, test=0.659) recall: (train=0.486, test=0.341) roc_auc: (train=0.913, test=0.768) total time=   0.5s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.704, test=0.570) f1: (train=0.552, test=0.472) precision: (train=0.806, test=0.703) recall: (train=0.420, test=0.355) roc_auc: (train=0.858, test=0.782) total time=   0.2s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.715, test=0.551) f1: (train=0.547, test=0.430) precision: (train=0.836, test=0.690) recall: (train=0.406, test=0.313) roc_auc: (train=0.864, test=0.778) total time=   0.3s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.710, test=0.537) f1: (train=0.552, test=0.458) precision: (train=0.811, test=0.667) recall: (train=0.418, test=0.349) roc_auc: (train=0.856, test=0.768) total time=   0.3s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.819, test=0.568) f1: (train=0.631, test=0.467) precision: (train=0.891, test=0.691) recall: (train=0.488, test=0.352) roc_auc: (train=0.922, test=0.778) total time=   0.7s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.827, test=0.541) f1: (train=0.637, test=0.430) precision: (train=0.928, test=0.690) recall: (train=0.485, test=0.313) roc_auc: (train=0.922, test=0.772) total time=   0.6s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.824, test=0.532) f1: (train=0.641, test=0.455) precision: (train=0.899, test=0.661) recall: (train=0.499, test=0.347) roc_auc: (train=0.922, test=0.766) total time=   0.6s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.697, test=0.572) f1: (train=0.544, test=0.466) precision: (train=0.800, test=0.704) recall: (train=0.412, test=0.349) roc_auc: (train=0.855, test=0.783) total time=   0.3s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.710, test=0.550) f1: (train=0.547, test=0.432) precision: (train=0.835, test=0.704) recall: (train=0.407, test=0.312) roc_auc: (train=0.861, test=0.778) total time=   0.2s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.705, test=0.537) f1: (train=0.548, test=0.459) precision: (train=0.802, test=0.666) recall: (train=0.416, test=0.350) roc_auc: (train=0.855, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.811, test=0.566) f1: (train=0.628, test=0.461) precision: (train=0.891, test=0.690) recall: (train=0.485, test=0.346) roc_auc: (train=0.918, test=0.777) total time=   0.6s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.825, test=0.542) f1: (train=0.633, test=0.426) precision: (train=0.921, test=0.687) recall: (train=0.482, test=0.308) roc_auc: (train=0.923, test=0.772) total time=   0.5s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.814, test=0.534) f1: (train=0.632, test=0.453) precision: (train=0.895, test=0.660) recall: (train=0.488, test=0.345) roc_auc: (train=0.916, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.695, test=0.573) f1: (train=0.539, test=0.468) precision: (train=0.800, test=0.711) recall: (train=0.406, test=0.349) roc_auc: (train=0.855, test=0.783) total time=   0.3s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.706, test=0.551) f1: (train=0.544, test=0.430) precision: (train=0.827, test=0.699) recall: (train=0.405, test=0.311) roc_auc: (train=0.859, test=0.777) total time=   0.3s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.703, test=0.542) f1: (train=0.548, test=0.454) precision: (train=0.804, test=0.666) recall: (train=0.416, test=0.345) roc_auc: (train=0.853, test=0.769) total time=   0.2s
# [CV 1/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.806, test=0.569) f1: (train=0.620, test=0.462) precision: (train=0.881, test=0.700) recall: (train=0.478, test=0.345) roc_auc: (train=0.916, test=0.778) total time=   0.5s
# [CV 2/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.819, test=0.543) f1: (train=0.626, test=0.428) precision: (train=0.910, test=0.684) recall: (train=0.477, test=0.311) roc_auc: (train=0.921, test=0.772) total time=   0.5s
# [CV 3/3] END alpha=0, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.805, test=0.538) f1: (train=0.624, test=0.451) precision: (train=0.881, test=0.660) recall: (train=0.484, test=0.343) roc_auc: (train=0.911, test=0.767) total time=   0.6s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.573) f1: (train=0.547, test=0.472) precision: (train=0.803, test=0.707) recall: (train=0.415, test=0.354) roc_auc: (train=0.857, test=0.782) total time=   0.3s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.713, test=0.550) f1: (train=0.547, test=0.431) precision: (train=0.835, test=0.697) recall: (train=0.407, test=0.312) roc_auc: (train=0.862, test=0.778) total time=   0.3s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.707, test=0.539) f1: (train=0.550, test=0.457) precision: (train=0.805, test=0.669) recall: (train=0.417, test=0.347) roc_auc: (train=0.856, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.819, test=0.567) f1: (train=0.636, test=0.463) precision: (train=0.889, test=0.690) recall: (train=0.495, test=0.349) roc_auc: (train=0.921, test=0.778) total time=   0.6s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.832, test=0.542) f1: (train=0.637, test=0.429) precision: (train=0.920, test=0.691) recall: (train=0.487, test=0.311) roc_auc: (train=0.927, test=0.772) total time=   0.6s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.822, test=0.532) f1: (train=0.645, test=0.445) precision: (train=0.895, test=0.649) recall: (train=0.504, test=0.339) roc_auc: (train=0.920, test=0.765) total time=   0.7s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.697, test=0.574) f1: (train=0.543, test=0.471) precision: (train=0.800, test=0.707) recall: (train=0.411, test=0.353) roc_auc: (train=0.856, test=0.784) total time=   0.2s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.707, test=0.551) f1: (train=0.547, test=0.427) precision: (train=0.830, test=0.695) recall: (train=0.408, test=0.308) roc_auc: (train=0.859, test=0.778) total time=   0.3s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.704, test=0.540) f1: (train=0.544, test=0.453) precision: (train=0.801, test=0.666) recall: (train=0.412, test=0.344) roc_auc: (train=0.855, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.812, test=0.574) f1: (train=0.632, test=0.459) precision: (train=0.890, test=0.703) recall: (train=0.490, test=0.341) roc_auc: (train=0.919, test=0.778) total time=   0.6s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.823, test=0.542) f1: (train=0.626, test=0.423) precision: (train=0.902, test=0.681) recall: (train=0.479, test=0.307) roc_auc: (train=0.924, test=0.772) total time=   0.5s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.813, test=0.535) f1: (train=0.637, test=0.448) precision: (train=0.890, test=0.659) recall: (train=0.496, test=0.339) roc_auc: (train=0.916, test=0.767) total time=   0.5s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.694, test=0.575) f1: (train=0.538, test=0.465) precision: (train=0.797, test=0.707) recall: (train=0.406, test=0.346) roc_auc: (train=0.854, test=0.784) total time=   0.2s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.704, test=0.550) f1: (train=0.543, test=0.430) precision: (train=0.827, test=0.699) recall: (train=0.405, test=0.311) roc_auc: (train=0.857, test=0.777) total time=   0.2s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.542) f1: (train=0.542, test=0.454) precision: (train=0.798, test=0.670) recall: (train=0.410, test=0.344) roc_auc: (train=0.853, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.803, test=0.571) f1: (train=0.622, test=0.458) precision: (train=0.884, test=0.701) recall: (train=0.480, test=0.340) roc_auc: (train=0.915, test=0.778) total time=   0.5s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.817, test=0.543) f1: (train=0.621, test=0.426) precision: (train=0.902, test=0.690) recall: (train=0.474, test=0.308) roc_auc: (train=0.921, test=0.772) total time=   0.6s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.803, test=0.535) f1: (train=0.628, test=0.448) precision: (train=0.880, test=0.656) recall: (train=0.488, test=0.340) roc_auc: (train=0.911, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.573) f1: (train=0.548, test=0.467) precision: (train=0.804, test=0.702) recall: (train=0.416, test=0.349) roc_auc: (train=0.857, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.713, test=0.549) f1: (train=0.545, test=0.429) precision: (train=0.834, test=0.700) recall: (train=0.405, test=0.310) roc_auc: (train=0.862, test=0.777) total time=   0.3s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.708, test=0.540) f1: (train=0.551, test=0.458) precision: (train=0.803, test=0.665) recall: (train=0.419, test=0.349) roc_auc: (train=0.856, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.817, test=0.569) f1: (train=0.636, test=0.464) precision: (train=0.890, test=0.697) recall: (train=0.495, test=0.348) roc_auc: (train=0.922, test=0.779) total time=   0.5s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.832, test=0.544) f1: (train=0.636, test=0.430) precision: (train=0.921, test=0.689) recall: (train=0.486, test=0.312) roc_auc: (train=0.927, test=0.772) total time=   0.5s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.822, test=0.534) f1: (train=0.642, test=0.445) precision: (train=0.897, test=0.654) recall: (train=0.500, test=0.337) roc_auc: (train=0.920, test=0.766) total time=   0.6s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.697, test=0.574) f1: (train=0.543, test=0.471) precision: (train=0.800, test=0.705) recall: (train=0.411, test=0.354) roc_auc: (train=0.855, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.707, test=0.551) f1: (train=0.546, test=0.430) precision: (train=0.831, test=0.699) recall: (train=0.406, test=0.310) roc_auc: (train=0.860, test=0.778) total time=   0.2s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.705, test=0.540) f1: (train=0.547, test=0.453) precision: (train=0.803, test=0.664) recall: (train=0.415, test=0.344) roc_auc: (train=0.855, test=0.769) total time=   0.3s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.810, test=0.567) f1: (train=0.629, test=0.460) precision: (train=0.881, test=0.695) recall: (train=0.490, test=0.343) roc_auc: (train=0.919, test=0.777) total time=   0.7s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.823, test=0.543) f1: (train=0.626, test=0.427) precision: (train=0.903, test=0.681) recall: (train=0.479, test=0.311) roc_auc: (train=0.925, test=0.772) total time=   0.7s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.810, test=0.535) f1: (train=0.634, test=0.451) precision: (train=0.886, test=0.658) recall: (train=0.494, test=0.343) roc_auc: (train=0.914, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.694, test=0.573) f1: (train=0.538, test=0.468) precision: (train=0.799, test=0.710) recall: (train=0.406, test=0.349) roc_auc: (train=0.855, test=0.784) total time=   0.2s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.703, test=0.550) f1: (train=0.543, test=0.429) precision: (train=0.827, test=0.697) recall: (train=0.404, test=0.310) roc_auc: (train=0.857, test=0.777) total time=   0.2s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.541) f1: (train=0.540, test=0.451) precision: (train=0.798, test=0.667) recall: (train=0.409, test=0.341) roc_auc: (train=0.853, test=0.768) total time=   0.3s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.802, test=0.574) f1: (train=0.622, test=0.462) precision: (train=0.877, test=0.704) recall: (train=0.482, test=0.343) roc_auc: (train=0.914, test=0.778) total time=   0.5s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.815, test=0.541) f1: (train=0.620, test=0.428) precision: (train=0.898, test=0.691) recall: (train=0.474, test=0.310) roc_auc: (train=0.920, test=0.772) total time=   0.6s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.800, test=0.535) f1: (train=0.627, test=0.450) precision: (train=0.875, test=0.653) recall: (train=0.488, test=0.343) roc_auc: (train=0.910, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.574) f1: (train=0.545, test=0.468) precision: (train=0.804, test=0.700) recall: (train=0.413, test=0.352) roc_auc: (train=0.857, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.713, test=0.550) f1: (train=0.547, test=0.429) precision: (train=0.833, test=0.699) recall: (train=0.407, test=0.310) roc_auc: (train=0.862, test=0.778) total time=   0.2s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.708, test=0.539) f1: (train=0.553, test=0.458) precision: (train=0.809, test=0.666) recall: (train=0.420, test=0.349) roc_auc: (train=0.857, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.817, test=0.568) f1: (train=0.636, test=0.459) precision: (train=0.891, test=0.691) recall: (train=0.494, test=0.343) roc_auc: (train=0.921, test=0.778) total time=   0.5s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.829, test=0.541) f1: (train=0.635, test=0.430) precision: (train=0.918, test=0.687) recall: (train=0.485, test=0.313) roc_auc: (train=0.926, test=0.772) total time=   0.6s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.822, test=0.533) f1: (train=0.642, test=0.441) precision: (train=0.900, test=0.650) recall: (train=0.500, test=0.334) roc_auc: (train=0.919, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.697, test=0.574) f1: (train=0.541, test=0.464) precision: (train=0.800, test=0.700) recall: (train=0.409, test=0.348) roc_auc: (train=0.855, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.708, test=0.551) f1: (train=0.546, test=0.431) precision: (train=0.832, test=0.700) recall: (train=0.407, test=0.311) roc_auc: (train=0.860, test=0.778) total time=   0.2s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.703, test=0.539) f1: (train=0.545, test=0.454) precision: (train=0.799, test=0.663) recall: (train=0.414, test=0.346) roc_auc: (train=0.854, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.809, test=0.568) f1: (train=0.625, test=0.460) precision: (train=0.880, test=0.695) recall: (train=0.485, test=0.344) roc_auc: (train=0.918, test=0.779) total time=   0.5s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.821, test=0.542) f1: (train=0.628, test=0.425) precision: (train=0.903, test=0.679) recall: (train=0.482, test=0.310) roc_auc: (train=0.924, test=0.772) total time=   0.6s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.810, test=0.536) f1: (train=0.633, test=0.448) precision: (train=0.880, test=0.652) recall: (train=0.495, test=0.341) roc_auc: (train=0.914, test=0.767) total time=   0.6s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.693, test=0.574) f1: (train=0.538, test=0.468) precision: (train=0.798, test=0.708) recall: (train=0.406, test=0.349) roc_auc: (train=0.854, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.703, test=0.550) f1: (train=0.544, test=0.430) precision: (train=0.827, test=0.698) recall: (train=0.406, test=0.311) roc_auc: (train=0.857, test=0.778) total time=   0.2s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.541) f1: (train=0.545, test=0.454) precision: (train=0.802, test=0.669) recall: (train=0.413, test=0.343) roc_auc: (train=0.853, test=0.769) total time=   0.2s
# [CV 1/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.804, test=0.571) f1: (train=0.626, test=0.460) precision: (train=0.880, test=0.700) recall: (train=0.485, test=0.343) roc_auc: (train=0.916, test=0.779) total time=   0.5s
# [CV 2/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.814, test=0.542) f1: (train=0.621, test=0.429) precision: (train=0.899, test=0.697) recall: (train=0.474, test=0.310) roc_auc: (train=0.920, test=0.772) total time=   0.6s
# [CV 3/3] END alpha=0.25, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.800, test=0.535) f1: (train=0.626, test=0.452) precision: (train=0.873, test=0.656) recall: (train=0.488, test=0.344) roc_auc: (train=0.910, test=0.767) total time=   0.5s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.698, test=0.573) f1: (train=0.545, test=0.468) precision: (train=0.802, test=0.703) recall: (train=0.413, test=0.351) roc_auc: (train=0.857, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.710, test=0.550) f1: (train=0.548, test=0.428) precision: (train=0.831, test=0.691) recall: (train=0.409, test=0.310) roc_auc: (train=0.860, test=0.778) total time=   0.3s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.706, test=0.541) f1: (train=0.550, test=0.458) precision: (train=0.805, test=0.667) recall: (train=0.417, test=0.349) roc_auc: (train=0.856, test=0.769) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.816, test=0.571) f1: (train=0.635, test=0.465) precision: (train=0.883, test=0.698) recall: (train=0.496, test=0.348) roc_auc: (train=0.922, test=0.777) total time=   0.7s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.826, test=0.542) f1: (train=0.630, test=0.433) precision: (train=0.909, test=0.683) recall: (train=0.482, test=0.317) roc_auc: (train=0.926, test=0.773) total time=   0.7s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.815, test=0.533) f1: (train=0.640, test=0.447) precision: (train=0.883, test=0.650) recall: (train=0.502, test=0.340) roc_auc: (train=0.918, test=0.766) total time=   0.6s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.695, test=0.574) f1: (train=0.536, test=0.463) precision: (train=0.797, test=0.700) recall: (train=0.404, test=0.346) roc_auc: (train=0.855, test=0.784) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.707, test=0.551) f1: (train=0.543, test=0.431) precision: (train=0.830, test=0.699) recall: (train=0.404, test=0.312) roc_auc: (train=0.859, test=0.778) total time=   0.2s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.541) f1: (train=0.541, test=0.454) precision: (train=0.800, test=0.667) recall: (train=0.409, test=0.344) roc_auc: (train=0.854, test=0.768) total time=   0.3s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.804, test=0.573) f1: (train=0.626, test=0.463) precision: (train=0.883, test=0.698) recall: (train=0.485, test=0.347) roc_auc: (train=0.916, test=0.781) total time=   0.6s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.818, test=0.542) f1: (train=0.623, test=0.432) precision: (train=0.900, test=0.695) recall: (train=0.476, test=0.313) roc_auc: (train=0.922, test=0.772) total time=   0.6s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.804, test=0.536) f1: (train=0.629, test=0.450) precision: (train=0.873, test=0.648) recall: (train=0.492, test=0.345) roc_auc: (train=0.911, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.690, test=0.574) f1: (train=0.532, test=0.464) precision: (train=0.791, test=0.704) recall: (train=0.401, test=0.346) roc_auc: (train=0.853, test=0.785) total time=   0.3s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.551) f1: (train=0.541, test=0.428) precision: (train=0.825, test=0.697) recall: (train=0.403, test=0.308) roc_auc: (train=0.856, test=0.778) total time=   0.3s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.697, test=0.544) f1: (train=0.538, test=0.456) precision: (train=0.795, test=0.672) recall: (train=0.407, test=0.345) roc_auc: (train=0.852, test=0.769) total time=   0.3s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.795, test=0.571) f1: (train=0.616, test=0.465) precision: (train=0.870, test=0.703) recall: (train=0.476, test=0.348) roc_auc: (train=0.912, test=0.780) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.810, test=0.542) f1: (train=0.613, test=0.425) precision: (train=0.896, test=0.694) recall: (train=0.466, test=0.307) roc_auc: (train=0.917, test=0.773) total time=   0.6s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.797, test=0.537) f1: (train=0.627, test=0.448) precision: (train=0.870, test=0.650) recall: (train=0.490, test=0.341) roc_auc: (train=0.909, test=0.767) total time=   0.6s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.699, test=0.572) f1: (train=0.544, test=0.470) precision: (train=0.801, test=0.702) recall: (train=0.411, test=0.354) roc_auc: (train=0.857, test=0.783) total time=   0.3s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.710, test=0.551) f1: (train=0.546, test=0.427) precision: (train=0.829, test=0.690) recall: (train=0.407, test=0.309) roc_auc: (train=0.861, test=0.779) total time=   0.4s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.706, test=0.541) f1: (train=0.547, test=0.456) precision: (train=0.809, test=0.667) recall: (train=0.414, test=0.347) roc_auc: (train=0.856, test=0.769) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.814, test=0.570) f1: (train=0.630, test=0.461) precision: (train=0.881, test=0.694) recall: (train=0.490, test=0.345) roc_auc: (train=0.922, test=0.777) total time=   0.6s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.825, test=0.542) f1: (train=0.629, test=0.428) precision: (train=0.904, test=0.686) recall: (train=0.482, test=0.311) roc_auc: (train=0.926, test=0.774) total time=   0.5s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.814, test=0.533) f1: (train=0.637, test=0.448) precision: (train=0.882, test=0.651) recall: (train=0.499, test=0.341) roc_auc: (train=0.917, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.694, test=0.573) f1: (train=0.538, test=0.470) precision: (train=0.798, test=0.709) recall: (train=0.406, test=0.352) roc_auc: (train=0.855, test=0.784) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.705, test=0.551) f1: (train=0.541, test=0.430) precision: (train=0.823, test=0.697) recall: (train=0.403, test=0.311) roc_auc: (train=0.858, test=0.779) total time=   0.2s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.542) f1: (train=0.543, test=0.450) precision: (train=0.802, test=0.664) recall: (train=0.410, test=0.340) roc_auc: (train=0.854, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.803, test=0.572) f1: (train=0.622, test=0.461) precision: (train=0.878, test=0.692) recall: (train=0.482, test=0.346) roc_auc: (train=0.914, test=0.780) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.817, test=0.541) f1: (train=0.622, test=0.434) precision: (train=0.900, test=0.688) recall: (train=0.475, test=0.317) roc_auc: (train=0.922, test=0.771) total time=   0.6s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.806, test=0.534) f1: (train=0.633, test=0.450) precision: (train=0.875, test=0.651) recall: (train=0.496, test=0.344) roc_auc: (train=0.913, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.691, test=0.574) f1: (train=0.535, test=0.467) precision: (train=0.796, test=0.711) recall: (train=0.403, test=0.348) roc_auc: (train=0.854, test=0.784) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.552) f1: (train=0.541, test=0.428) precision: (train=0.823, test=0.694) recall: (train=0.403, test=0.310) roc_auc: (train=0.856, test=0.779) total time=   0.2s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.697, test=0.543) f1: (train=0.538, test=0.454) precision: (train=0.796, test=0.671) recall: (train=0.406, test=0.343) roc_auc: (train=0.853, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.795, test=0.571) f1: (train=0.616, test=0.464) precision: (train=0.872, test=0.699) recall: (train=0.476, test=0.348) roc_auc: (train=0.910, test=0.780) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.809, test=0.543) f1: (train=0.614, test=0.430) precision: (train=0.893, test=0.698) recall: (train=0.468, test=0.311) roc_auc: (train=0.917, test=0.773) total time=   0.7s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.797, test=0.538) f1: (train=0.622, test=0.445) precision: (train=0.869, test=0.644) recall: (train=0.485, test=0.340) roc_auc: (train=0.909, test=0.766) total time=   0.5s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.698, test=0.573) f1: (train=0.547, test=0.466) precision: (train=0.803, test=0.700) recall: (train=0.415, test=0.349) roc_auc: (train=0.856, test=0.783) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.710, test=0.550) f1: (train=0.546, test=0.430) precision: (train=0.830, test=0.694) recall: (train=0.407, test=0.311) roc_auc: (train=0.861, test=0.779) total time=   0.2s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.707, test=0.541) f1: (train=0.549, test=0.452) precision: (train=0.810, test=0.666) recall: (train=0.415, test=0.343) roc_auc: (train=0.856, test=0.768) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.813, test=0.572) f1: (train=0.632, test=0.465) precision: (train=0.880, test=0.700) recall: (train=0.493, test=0.348) roc_auc: (train=0.921, test=0.778) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.825, test=0.541) f1: (train=0.625, test=0.431) precision: (train=0.905, test=0.687) recall: (train=0.478, test=0.314) roc_auc: (train=0.926, test=0.772) total time=   0.5s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.814, test=0.533) f1: (train=0.638, test=0.446) precision: (train=0.881, test=0.647) recall: (train=0.500, test=0.340) roc_auc: (train=0.917, test=0.767) total time=   0.5s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.694, test=0.574) f1: (train=0.539, test=0.468) precision: (train=0.799, test=0.706) recall: (train=0.407, test=0.350) roc_auc: (train=0.855, test=0.784) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.705, test=0.551) f1: (train=0.542, test=0.430) precision: (train=0.825, test=0.696) recall: (train=0.404, test=0.311) roc_auc: (train=0.859, test=0.778) total time=   0.2s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.701, test=0.542) f1: (train=0.542, test=0.454) precision: (train=0.800, test=0.668) recall: (train=0.410, test=0.344) roc_auc: (train=0.854, test=0.768) total time=   0.2s
# ...
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.685, test=0.566) f1: (train=0.533, test=0.440) precision: (train=0.795, test=0.714) recall: (train=0.401, test=0.318) roc_auc: (train=0.850, test=0.784) total time=   0.2s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.690, test=0.548) f1: (train=0.531, test=0.461) precision: (train=0.790, test=0.669) recall: (train=0.400, test=0.352) roc_auc: (train=0.849, test=0.773) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.789, test=0.539) f1: (train=0.607, test=0.453) precision: (train=0.869, test=0.674) recall: (train=0.467, test=0.341) roc_auc: (train=0.909, test=0.775) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.800, test=0.557) f1: (train=0.614, test=0.440) precision: (train=0.881, test=0.707) recall: (train=0.472, test=0.319) roc_auc: (train=0.914, test=0.779) total time=   0.6s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.796, test=0.540) f1: (train=0.611, test=0.460) precision: (train=0.866, test=0.659) recall: (train=0.471, test=0.354) roc_auc: (train=0.906, test=0.769) total time=   0.5s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.683, test=0.546) f1: (train=0.535, test=0.457) precision: (train=0.789, test=0.675) recall: (train=0.405, test=0.345) roc_auc: (train=0.849, test=0.780) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.681, test=0.567) f1: (train=0.528, test=0.439) precision: (train=0.789, test=0.708) recall: (train=0.397, test=0.318) roc_auc: (train=0.848, test=0.784) total time=   0.2s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.686, test=0.547) f1: (train=0.532, test=0.460) precision: (train=0.788, test=0.669) recall: (train=0.401, test=0.350) roc_auc: (train=0.847, test=0.772) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.780, test=0.541) f1: (train=0.602, test=0.455) precision: (train=0.859, test=0.678) recall: (train=0.463, test=0.342) roc_auc: (train=0.905, test=0.776) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.789, test=0.557) f1: (train=0.603, test=0.434) precision: (train=0.873, test=0.707) recall: (train=0.460, test=0.313) roc_auc: (train=0.908, test=0.780) total time=   0.6s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.785, test=0.543) f1: (train=0.603, test=0.461) precision: (train=0.862, test=0.665) recall: (train=0.463, test=0.353) roc_auc: (train=0.901, test=0.770) total time=   0.5s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.680, test=0.547) f1: (train=0.531, test=0.456) precision: (train=0.786, test=0.677) recall: (train=0.401, test=0.343) roc_auc: (train=0.847, test=0.780) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.679, test=0.566) f1: (train=0.525, test=0.437) precision: (train=0.788, test=0.714) recall: (train=0.393, test=0.315) roc_auc: (train=0.846, test=0.784) total time=   0.2s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.684, test=0.549) f1: (train=0.527, test=0.460) precision: (train=0.783, test=0.667) recall: (train=0.397, test=0.351) roc_auc: (train=0.846, test=0.772) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.776, test=0.542) f1: (train=0.600, test=0.447) precision: (train=0.863, test=0.675) recall: (train=0.460, test=0.334) roc_auc: (train=0.903, test=0.776) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.778, test=0.558) f1: (train=0.595, test=0.431) precision: (train=0.865, test=0.705) recall: (train=0.453, test=0.311) roc_auc: (train=0.904, test=0.780) total time=   0.6s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.25, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.779, test=0.545) f1: (train=0.598, test=0.458) precision: (train=0.861, test=0.671) recall: (train=0.459, test=0.348) roc_auc: (train=0.898, test=0.771) total time=   0.6s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.687, test=0.545) f1: (train=0.538, test=0.459) precision: (train=0.793, test=0.673) recall: (train=0.407, test=0.348) roc_auc: (train=0.851, test=0.780) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.686, test=0.566) f1: (train=0.530, test=0.442) precision: (train=0.789, test=0.714) recall: (train=0.398, test=0.320) roc_auc: (train=0.849, test=0.784) total time=   0.3s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.690, test=0.547) f1: (train=0.531, test=0.460) precision: (train=0.788, test=0.671) recall: (train=0.400, test=0.350) roc_auc: (train=0.849, test=0.772) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.790, test=0.537) f1: (train=0.611, test=0.458) precision: (train=0.870, test=0.678) recall: (train=0.471, test=0.345) roc_auc: (train=0.910, test=0.774) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.799, test=0.560) f1: (train=0.614, test=0.435) precision: (train=0.879, test=0.703) recall: (train=0.472, test=0.315) roc_auc: (train=0.914, test=0.780) total time=   0.5s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.796, test=0.537) f1: (train=0.612, test=0.459) precision: (train=0.868, test=0.659) recall: (train=0.473, test=0.353) roc_auc: (train=0.907, test=0.769) total time=   0.6s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.683, test=0.545) f1: (train=0.534, test=0.456) precision: (train=0.789, test=0.673) recall: (train=0.403, test=0.345) roc_auc: (train=0.849, test=0.781) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.682, test=0.566) f1: (train=0.527, test=0.440) precision: (train=0.789, test=0.712) recall: (train=0.395, test=0.318) roc_auc: (train=0.848, test=0.784) total time=   0.3s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.684, test=0.547) f1: (train=0.531, test=0.460) precision: (train=0.789, test=0.670) recall: (train=0.400, test=0.351) roc_auc: (train=0.847, test=0.772) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.781, test=0.539) f1: (train=0.604, test=0.457) precision: (train=0.860, test=0.674) recall: (train=0.465, test=0.346) roc_auc: (train=0.906, test=0.775) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.785, test=0.557) f1: (train=0.600, test=0.436) precision: (train=0.866, test=0.707) recall: (train=0.459, test=0.315) roc_auc: (train=0.907, test=0.780) total time=   0.6s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.25, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.784, test=0.542) f1: (train=0.602, test=0.461) precision: (train=0.861, test=0.669) recall: (train=0.463, test=0.352) roc_auc: (train=0.901, test=0.770) total time=   0.5s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.680, test=0.546) f1: (train=0.531, test=0.455) precision: (train=0.785, test=0.676) recall: (train=0.401, test=0.343) roc_auc: (train=0.846, test=0.780) total time=   0.2s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.679, test=0.567) f1: (train=0.524, test=0.436) precision: (train=0.788, test=0.711) recall: (train=0.392, test=0.315) roc_auc: (train=0.846, test=0.784) total time=   0.2s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=7, n_estimators=100; average_precision: (train=0.682, test=0.549) f1: (train=0.528, test=0.459) precision: (train=0.786, test=0.667) recall: (train=0.398, test=0.350) roc_auc: (train=0.846, test=0.773) total time=   0.2s
# [CV 1/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.774, test=0.543) f1: (train=0.596, test=0.455) precision: (train=0.858, test=0.676) recall: (train=0.457, test=0.342) roc_auc: (train=0.902, test=0.777) total time=   0.5s
# [CV 2/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.780, test=0.557) f1: (train=0.599, test=0.430) precision: (train=0.868, test=0.699) recall: (train=0.457, test=0.311) roc_auc: (train=0.905, test=0.780) total time=   0.6s
# [CV 3/3] END alpha=0.5, booster=gbtree, gamma=0.5, lambda=0.5, learning_rate=0.02, max_depth=9, n_estimators=100; average_precision: (train=0.777, test=0.541) f1: (train=0.598, test=0.457) precision: (train=0.853, test=0.664) recall: (train=0.460, test=0.348) roc_auc: (train=0.897, test=0.771) total time=   0.6s
# Duración búsqueda: 0 days 00:01:30.637200
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[27], line 75
#      73 modelos_75 = pd.DataFrame(ajuste_modelo_75)
#      74 # Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
# ---> 75 modelos_75.to_excel('C:\\Users\\mmene\\OneDrive\\Escritorio\\TESIS\\XGBoost\\PRUEBA_RESULTADO\\modelos_75.xlsx')
#      77 #80
#      78 # Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
#      79 ajuste_modelo_80 = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\excel\_openpyxl.py:61, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      57 from openpyxl.workbook import Workbook
#      59 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 61 super().__init__(
#      62     path,
#      63     mode=mode,
#      64     storage_options=storage_options,
#      65     if_sheet_exists=if_sheet_exists,
#      66     engine_kwargs=engine_kwargs,
#      67 )
#      69 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      70 # the file and later write to it
#      71 if "r+" in self._mode:  # Load from existing workbook
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\excel\_base.py:1246, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1242 self._handles = IOHandles(
#    1243     cast(IO[bytes], path), compression={"compression": None}
#    1244 )
#    1245 if not isinstance(path, ExcelWriter):
# -> 1246     self._handles = get_handle(
#    1247         path, mode, storage_options=storage_options, is_text=False
#    1248     )
#    1249 self._cur_sheet = None
#    1251 if date_format is None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\mmene\\OneDrive\\Escritorio\\TESIS\\XGBoost\\PRUEBA_RESULTADO\\modelos_75.xlsx'
