# %%
# BIBLIOTECAS NECESARIAS

# Bibliotecas para operaciones numéricas y manejo de datos
import numpy as np  # Operaciones numéricas
import pandas as pd  # Manejo de datos en formato tabular

# División del conjunto de datos y validación cruzada
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

# Modelos de clasificación
from sklearn.ensemble import RandomForestClassifier

# Importar todo el módulo de métricas
import sklearn.metrics

# Métricas de evaluación y reportes
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    PrecisionRecallDisplay,
    roc_curve, auc,
    classification_report,
    accuracy_score, precision_score, recall_score, f1_score
)

# Bibliotecas para gráficos
import matplotlib.pyplot as plt  # Gráficos básicos
import seaborn as sns  # Gráficos estadísticos, con menos código que matplotlib
import plotly.express as px  # Gráficos interactivos con interfaz sencilla y de alto nivel
import plotly.graph_objects as go  # Gráficos interactivos con interfaz más detallada y de bajo nivel

# Herramientas para iteradores
import itertools  # Herramientas funcionales para crear y utilizar iteradores

# Herramientas para preprocesamiento de datos y evaluación de modelos
from sklearn.preprocessing import StandardScaler  # Escalado de características para normalizar datos
from sklearn.model_selection import learning_curve  # Generación de curvas de aprendizaje para evaluar el rendimiento del modelo
from sklearn.model_selection import validation_curve  # Generación de curvas de validación para evaluar el rendimiento del modelo

# %%
credit_card = pd.read_csv('D:\\ISA\\default_of_credit_card_clients.csv', sep=';')

# %%
credit_card.head(10)
# Out:
#        X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...     X15     X16     X17  \
# 0   20000   2   2   1  24   2   2  -1  -1   -2  ...       0       0       0
# 1  120000   2   2   2  26  -1   2   0   0    0  ...    3272    3455    3261
# 2   90000   2   2   2  34   0   0   0   0    0  ...   14331   14948   15549
# 3   50000   2   2   1  37   0   0   0   0    0  ...   28314   28959   29547
# 4   50000   1   2   1  57  -1   0  -1   0    0  ...   20940   19146   19131
# 5   50000   1   1   2  37   0   0   0   0    0  ...   19394   19619   20024
# 6  500000   1   1   2  29   0   0   0   0    0  ...  542653  483003  473944
# 7  100000   2   2   2  23   0  -1  -1   0    0  ...     221    -159     567
# 8  140000   2   3   1  28   0   0   2   0    0  ...   12211   11793    3719
# 9   20000   1   3   2  35  -2  -2  -2  -2   -1  ...       0   13007   13912
#
#      X18    X19    X20    X21    X22    X23  Y
# 0      0    689      0      0      0      0  1
# 1      0   1000   1000   1000      0   2000  1
# 2   1518   1500   1000   1000   1000   5000  0
# 3   2000   2019   1200   1100   1069   1000  0
# 4   2000  36681  10000   9000    689    679  0
# 5   2500   1815    657   1000   1000    800  0
# 6  55000  40000  38000  20239  13750  13770  0
# 7    380    601      0    581   1687   1542  0
# 8   3329      0    432   1000   1000   1000  0
# 9      0      0      0  13007   1122      0  0
#
# [10 rows x 24 columns]

# %%
# Paso 1: Separar características (X) y la columna objetivo (y)
X = credit_card.drop(['Y'], axis=1)  # Eliminar la columna 'Y'
y = credit_card['Y']  # Conservar la columna 'Y'

# Paso 2: Crear un objeto StandardScaler
scaler = StandardScaler()

# Paso 3: Ajustar el escalador a las características y transformarlas
scaled = scaler.fit_transform(X)

# Paso 4: Convertir X_scaled de vuelta a un DataFrame
X_scaled = pd.DataFrame(scaled, columns=X.columns)

# Paso 5: Reunir X_scaled con la columna 'Class'
credit_card_scaled = pd.concat([X_scaled, y.reset_index(drop=True)], axis=1)

# Paso 6: Mostrar las primeras filas del DataFrame transformado
print(credit_card_scaled.head())
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -1.136720  0.810161  0.185828 -1.057295 -1.246020  1.794564  1.782348
# 1 -0.365981  0.810161  0.185828  0.858557 -1.029047 -0.874991  1.782348
# 2 -0.597202  0.810161  0.185828  0.858557 -0.161156  0.014861  0.111736
# 3 -0.905498  0.810161  0.185828 -1.057295  0.164303  0.014861  0.111736
# 4 -0.905498 -1.234323  0.185828 -1.057295  2.334029 -0.874991  0.111736
#
#          X8        X9       X10  ...       X15       X16       X17       X18  \
# 0 -0.696663 -0.666599 -1.530046  ... -0.672497 -0.663059 -0.652724 -0.341942
# 1  0.138865  0.188746  0.234917  ... -0.621636 -0.606229 -0.597966 -0.341942
# 2  0.138865  0.188746  0.234917  ... -0.449730 -0.417188 -0.391630 -0.250292
# 3  0.138865  0.188746  0.234917  ... -0.232373 -0.186729 -0.156579 -0.221191
# 4 -0.696663  0.188746  0.234917  ... -0.346997 -0.348137 -0.331482 -0.221191
#
#         X19       X20       X21       X22       X23  Y
# 0 -0.227086 -0.296801 -0.308063 -0.314136 -0.293382  1
# 1 -0.213588 -0.240005 -0.244230 -0.314136 -0.180878  1
# 2 -0.191887 -0.240005 -0.244230 -0.248683 -0.012122  0
# 3 -0.169361 -0.228645 -0.237846 -0.244166 -0.237130  0
# 4  1.335034  0.271165  0.266434 -0.269039 -0.255187  0
#
# [5 rows x 24 columns]

# %%
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)

X_resampled, y_resampled = ros.fit_resample(X_scaled,y)

credit_card_resampled = pd.DataFrame(X_resampled, columns=X.columns)
credit_card_resampled['Y'] = y_resampled

print(credit_card_resampled.head())
print(credit_card_resampled['Y'].value_counts())
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -1.136720  0.810161  0.185828 -1.057295 -1.246020  1.794564  1.782348
# 1 -0.365981  0.810161  0.185828  0.858557 -1.029047 -0.874991  1.782348
# 2 -0.597202  0.810161  0.185828  0.858557 -0.161156  0.014861  0.111736
# 3 -0.905498  0.810161  0.185828 -1.057295  0.164303  0.014861  0.111736
# 4 -0.905498 -1.234323  0.185828 -1.057295  2.334029 -0.874991  0.111736
#
#          X8        X9       X10  ...       X15       X16       X17       X18  \
# 0 -0.696663 -0.666599 -1.530046  ... -0.672497 -0.663059 -0.652724 -0.341942
# 1  0.138865  0.188746  0.234917  ... -0.621636 -0.606229 -0.597966 -0.341942
# 2  0.138865  0.188746  0.234917  ... -0.449730 -0.417188 -0.391630 -0.250292
# 3  0.138865  0.188746  0.234917  ... -0.232373 -0.186729 -0.156579 -0.221191
# 4 -0.696663  0.188746  0.234917  ... -0.346997 -0.348137 -0.331482 -0.221191
#
#         X19       X20       X21       X22       X23  Y
# 0 -0.227086 -0.296801 -0.308063 -0.314136 -0.293382  1
# 1 -0.213588 -0.240005 -0.244230 -0.314136 -0.180878  1
# 2 -0.191887 -0.240005 -0.244230 -0.248683 -0.012122  0
# 3 -0.169361 -0.228645 -0.237846 -0.244166 -0.237130  0
# 4  1.335034  0.271165  0.266434 -0.269039 -0.255187  0
#
# [5 rows x 24 columns]
# Y
# 1    23364
# 0    23364
# Name: count, dtype: int64

# %%
from matplotlib.lines import Line2D  # Para crear la leyenda personalizada
# VISUALIZACIÓN 3D DE LA DISTRIBUCIÓN DE CLASES EN DATOS DE TRANSACCIONES CON RUS

# Crear la figura y el gráfico 3D
fig = plt.figure(figsize=(12, 9))  # Tamaño de la figura
ax = fig.add_subplot(111, projection='3d')  # Crear un eje 3D en la figura

# Usar el colormap 'viridis' para asignar colores a las clases
cmap = plt.cm.viridis  # Cargar el colormap 'viridis', que asigna colores a las clases

# Definir colores específicos para cada clase (clase 0 y clase 1)
# Usamos el color más oscuro para la clase 0 y el amarillo para la clase 1
colors = [cmap(0), cmap(0.999999)]  # Primer color para clase 0, segundo color (amarillo) para clase 1

# Crear el gráfico de dispersión 3D, asignando colores según las clases
scatter = ax.scatter(
    X_resampled.iloc[:, 5],  # Coordenada X usando la columna 14 de X_scaled
    X_resampled.iloc[:, 4],  # Coordenada Y usando la columna 17 de X_scaled
    X_resampled.iloc[:, 11],  # Coordenada Z usando la columna 10 de X_scaled
    c=y_resampled,  # Asignar colores a los puntos basados en la variable 'y' (las clases)
    cmap=plt.cm.colors.ListedColormap(colors),  # Aplicar el colormap personalizado
    alpha=0.6  # Ajustar la transparencia de los puntos
)

# Etiquetar los ejes con los nombres de las variables correspondientes
ax.set_xlabel('X6', fontsize=12, labelpad=10)
ax.set_zlabel('X12', fontsize=12, labelpad=10)
ax.set_ylabel('X5', fontsize=12, labelpad=10)

# Agregar un título claro y centrado al gráfico
plt.title(
    'GRÁFICO DE DISPERSIÓN DE CLASES\nPOR INCUMPLIMIENTO DE PAGO CON RANDOM OVERSAMPLING (BD2)',  # Título con salto de línea
    fontsize=14,  # Tamaño de la fuente
    fontweight='bold',  # Poner el título en negrita
    color='#1C325B',  # Color azul oscuro
    loc='center',  # Centrar el título
    y=1  # Ajustar la posición vertical del título
)

# Ajustar la perspectiva del gráfico 3D para mejorar la visualización
ax.view_init(elev=20, azim=-60)  # Elevación y ángulo de azimut del gráfico 3D

# Crear los objetos de la leyenda con los colores definidos previamente para cada clase
handles = [
    Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[0], markersize=10),  # Clase 0 (no fraudulenta)
    Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[1], markersize=10)   # Clase 1 (fraudulenta)
]

etiq =  {0: f"No incumplió el pago", 1: f"Incumplió el pago"}

# Asignar las etiquetas correspondientes a las clases para la leyenda
labels = [etiq[0], etiq[1]]  # 'etiq' debe contener las etiquetas de las clases (asegurarse de que esté definida)

# Colocar la leyenda en la parte superior central del gráfico
ax.legend(
    handles=handles,  # Usar los objetos creados para la leyenda
    labels=labels,  # Etiquetas de las clases
    loc='upper center',  # Ubicación de la leyenda
    fontsize=12,  # Tamaño de la fuente de la leyenda
    title_fontsize=14,  # Tamaño de la fuente del título de la leyenda
    bbox_to_anchor=(0.9, 0.9)  # Posicionar la leyenda fuera del gráfico, en la parte derecha
)

# Mostrar el gráfico generado
plt.show()

# %%
# Calcula el recuento de las clases de transacción (no fraudulenta y fraudulenta) y los ordena por índice
class_counts = credit_card_resampled['Y'].value_counts().sort_index()

# Extrae los valores (recuentos) de las clases
valores = class_counts.values

# Define etiquetas para las clases (0: no fraudulenta, 1: fraudulenta)
# Estas etiquetas se utilizarán en el gráfico para representar cada segmento
etiq =  {0: f"pagó", 1: f"impago"}

# Crea un gráfico de pastel con Plotly Express
# 'values' representa el tamaño de cada segmento, y 'names' proporciona las etiquetas para cada segmento
fig = px.pie(credit_card_resampled, values=valores, names=etiq,
             title='<b>DISTRIBUCIÓN DE CLASES</b>',
             color_discrete_sequence=['#522258', '#FFE31A'],
             )

# Ajusta el tamaño del texto del porcentaje en el gráfico para mejorar la visibilidad
fig.update_traces(textinfo='percent', textfont_size=15)

# Centra el título y coloca la leyenda debajo del gráfico
fig.update_layout(
    title_x=0.5,  # Centra el título
    title_y=0.90,  # Ajusta la posición vertical del título
    showlegend=True,  # Activa la leyenda
    legend_orientation="h",  # Pone la leyenda horizontal
    legend_y=-0.05,  # Coloca la leyenda debajo del gráfico
    legend_x=0.2
)

# Muestra el gráfico
fig.show()

# %%
# 'HOLDOUT METHOD' para evaluar el rendimiento de un modelo de aprendizaje automático
# Este método divide el conjunto de datos en entrenamiento y prueba con diferentes tamaños de entrenamiento
# para evaluar cómo el rendimiento del modelo varía con el tamaño del conjunto de entrenamiento.

# Definir los diferentes tamaños para el conjunto de entrenamiento
train_sizes = [0.75,0.80,0.90]

# Crear una lista para almacenar los resultados de los diferentes conjuntos de entrenamiento y prueba
split_results = []

# Para cada tamaño de entrenamiento en train_sizes
for splits in train_sizes:
  # Se divide los datos X e y en conjuntos de entrenamiento y prueba con el tamaño especificado
  X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, train_size=splits, random_state=42)
  split_results.append((X_train, X_test, y_train, y_test))

# Mostrar las dimensiones de los conjuntos de entrenamiento y prueba para cada tamaño de entrenamiento
for i, (X_train, X_test, y_train, y_test) in enumerate(split_results):
  print(f"\033[1mConjunto con train_size={train_sizes[i]}\033[0m")
  print(f"Dimensión total es: {credit_card_resampled.shape}")
  print(f"X_train dimensión: {X_train.shape}, X_test dimensión: {X_test.shape}")
  print(f"y_train dimensión: {y_train.shape}, y_test dimensión: {y_test.shape}")
  print()
# Out:
# Conjunto con train_size=0.75
# Dimensión total es: (46728, 24)
# X_train dimensión: (35046, 23), X_test dimensión: (11682, 23)
# y_train dimensión: (35046,), y_test dimensión: (11682,)
#
# Conjunto con train_size=0.8
# Dimensión total es: (46728, 24)
# X_train dimensión: (37382, 23), X_test dimensión: (9346, 23)
# y_train dimensión: (37382,), y_test dimensión: (9346,)
#
# Conjunto con train_size=0.9
# Dimensión total es: (46728, 24)
# X_train dimensión: (42055, 23), X_test dimensión: (4673, 23)
# y_train dimensión: (42055,), y_test dimensión: (4673,)

# %%
# MODELO RANDOM FOREST

# Lista para almacenar el resultado del modelo para cada conjunto de entrenamiento/prueba
models_split_results = []

# Iterar sobre los conjuntos generados
for i, (X_train, X_test, y_train, y_test) in enumerate(split_results):

  # Definir las métricas de evaluación
  scores = ["precision", "recall", "roc_auc", "f1", "average_precision"]

  # Mostrar información sobre el conjunto actual
  print(f"\033[1mConjunto con train_size={train_sizes[i]}:\033[0m")

  # Crear el modelo RANDOM FOREST
  modeloRF = RandomForestClassifier(
      n_jobs = -1, # Utilizar todos los núcleos disponibles para acelerar el entrenamiento
      random_state = 42 # Semilla para la reproducibilidad de los resultados
      )

  # Definir los parámetros para GridSearchCV
  grid_search = {
      "n_estimators": [10,12,14,16,18,20,50,100,200], # Número de árboles en el bosque aleatorio
      "criterion": ["gini", "entropy"], # Criterio para la selección del umbral de
      "max_features": ["sqrt","log2"], # Número máximo de características a considerar
      "max_depth": [10,20,30], # Profundidad máxima de cada
      "min_samples_split": [2,5,10], # Número mínimo de muestras requeridas para dividir un nodo interno
      "min_samples_leaf": [1,2,4] # Número mínimo de muestras requeridas en cada hoja
      }

  # Medir tiempo de ejecución
  start = pd.Timestamp.now()

  # Configuración de GridSearchCV
  grid = GridSearchCV(
      modeloRF,
      grid_search,
      cv=3, # Número de particiones en la validación cruzada
      refit=False, # No volver a entrenar el mejor modelo encontrado en toda la búsqueda
      scoring=scores, # Métricas de evaluación a usar
      verbose = 3, # Mostrar información adicional durante la búsqueda
      return_train_score=True # Devolver los resultados de entrenamiento
      )

  # Ejecutar GridSearchCV para encontrar el mejor modelo
  model_grid = grid.fit(X_train, y_train)

  # Medir tiempo de ejecución de GridSearchCV
  end = pd.Timestamp.now()
  print(f"Duración búsqueda: {end-start}")

  # Almacenar los resultados en la list 'models_split_results'
  models_split_results.append(model_grid.cv_results_)

  # Guardar modelos en un DataFrame
modelos_GSCV1= pd.DataFrame(models_split_results)

model_75 = models_split_results[0]
model_80 = models_split_results[1]
model_90 = models_split_results[2]

#75
# Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
ajuste_modelo_75 = []

# Recorre cada índice 'i' basado en la longitud de los tiempos medios de ajuste ('mean_fit_time')
for i in range(len(model_75['mean_fit_time'])):
  # Crea un diccionario 'execution' para la ejecución actual, extrayendo el valor correspondiente al índice 'i' de cada clave en 'resultados_modelo_75'
  execution = {key: value[i] for key, value in model_75.items()}
  # Añade el diccionario de resultados de la ejecución actual a la lista 'ajuste_modelo_80'
  ajuste_modelo_75.append(execution)

# Convierte la lista de diccionarios 'ajuste_modelo_75' en un DataFrame de pandas para facilitar su manipulación y análisis
modelos_75 = pd.DataFrame(ajuste_modelo_75)
# Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
modelos_75.to_excel('D:\\ISA\\COMPARACIONES\\modelos_75_ROS.xlsx')

#80
# Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
ajuste_modelo_80 = []

# Recorre cada índice 'i' basado en la longitud de los tiempos medios de ajuste ('mean_fit_time')
for i in range(len(model_80['mean_fit_time'])):
  # Crea un diccionario 'execution' para la ejecución actual, extrayendo el valor correspondiente al índice 'i' de cada clave en 'resultados_modelo_75'
  execution = {key: value[i] for key, value in model_80.items()}
  # Añade el diccionario de resultados de la ejecución actual a la lista 'ajuste_modelo_80'
  ajuste_modelo_80.append(execution)

# Convierte la lista de diccionarios 'ajuste_modelo_80' en un DataFrame de pandas para facilitar su manipulación y análisis
modelos_80 = pd.DataFrame(ajuste_modelo_80)
# Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
modelos_80.to_excel('D:\\ISA\\COMPARACIONES\\modelos_80_ROS.xlsx')


#90
# Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
ajuste_modelo_90 = []

# Recorre cada índice 'i' basado en la longitud de los tiempos medios de ajuste ('mean_fit_time')
for i in range(len(model_90['mean_fit_time'])):
  # Crea un diccionario 'execution' para la ejecución actual, extrayendo el valor correspondiente al índice 'i' de cada clave en 'resultados_modelo_75'
  execution = {key: value[i] for key, value in model_90.items()}
  # Añade el diccionario de resultados de la ejecución actual a la lista 'ajuste_modelo_80'
  ajuste_modelo_90.append(execution)

# Convierte la lista de diccionarios 'ajuste_modelo_90' en un DataFrame de pandas para facilitar su manipulación y análisis
modelos_90 = pd.DataFrame(ajuste_modelo_90)
# Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
modelos_90.to_excel('D:\\ISA\\COMPARACIONES\\modelos_90_ROS.xlsx')
# Out:
# Conjunto con train_size=0.75:
# Fitting 3 folds for each of 972 candidates, totalling 2916 fits
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10; average_precision: (train=0.873, test=0.822) f1: (train=0.762, test=0.723) precision: (train=0.828, test=0.784) recall: (train=0.706, test=0.670) roc_auc: (train=0.865, test=0.818) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10; average_precision: (train=0.874, test=0.822) f1: (train=0.755, test=0.721) precision: (train=0.830, test=0.791) recall: (train=0.692, test=0.663) roc_auc: (train=0.866, test=0.823) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10; average_precision: (train=0.878, test=0.814) f1: (train=0.768, test=0.723) precision: (train=0.833, test=0.775) recall: (train=0.713, test=0.678) roc_auc: (train=0.870, test=0.816) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=12; average_precision: (train=0.874, test=0.823) f1: (train=0.764, test=0.722) precision: (train=0.835, test=0.787) recall: (train=0.703, test=0.667) roc_auc: (train=0.867, test=0.820) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=12; average_precision: (train=0.876, test=0.823) f1: (train=0.760, test=0.722) precision: (train=0.834, test=0.794) recall: (train=0.698, test=0.662) roc_auc: (train=0.868, test=0.824) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=12; average_precision: (train=0.880, test=0.818) f1: (train=0.770, test=0.726) precision: (train=0.835, test=0.779) recall: (train=0.714, test=0.679) roc_auc: (train=0.872, test=0.817) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=14; average_precision: (train=0.877, test=0.826) f1: (train=0.767, test=0.726) precision: (train=0.837, test=0.788) recall: (train=0.708, test=0.673) roc_auc: (train=0.870, test=0.822) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=14; average_precision: (train=0.876, test=0.826) f1: (train=0.758, test=0.723) precision: (train=0.834, test=0.796) recall: (train=0.695, test=0.662) roc_auc: (train=0.869, test=0.827) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=14; average_precision: (train=0.881, test=0.821) f1: (train=0.773, test=0.727) precision: (train=0.836, test=0.779) recall: (train=0.718, test=0.682) roc_auc: (train=0.873, test=0.819) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=16; average_precision: (train=0.878, test=0.827) f1: (train=0.767, test=0.726) precision: (train=0.838, test=0.792) recall: (train=0.707, test=0.670) roc_auc: (train=0.871, test=0.824) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=16; average_precision: (train=0.878, test=0.827) f1: (train=0.760, test=0.724) precision: (train=0.837, test=0.799) recall: (train=0.696, test=0.662) roc_auc: (train=0.870, test=0.828) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=16; average_precision: (train=0.882, test=0.823) f1: (train=0.775, test=0.729) precision: (train=0.838, test=0.781) recall: (train=0.721, test=0.684) roc_auc: (train=0.875, test=0.820) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=18; average_precision: (train=0.880, test=0.828) f1: (train=0.769, test=0.728) precision: (train=0.841, test=0.793) recall: (train=0.709, test=0.672) roc_auc: (train=0.873, test=0.825) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=18; average_precision: (train=0.878, test=0.828) f1: (train=0.760, test=0.726) precision: (train=0.838, test=0.800) recall: (train=0.696, test=0.665) roc_auc: (train=0.871, test=0.829) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=18; average_precision: (train=0.883, test=0.823) f1: (train=0.776, test=0.731) precision: (train=0.840, test=0.783) recall: (train=0.721, test=0.686) roc_auc: (train=0.876, test=0.820) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20; average_precision: (train=0.881, test=0.829) f1: (train=0.768, test=0.728) precision: (train=0.841, test=0.795) recall: (train=0.706, test=0.671) roc_auc: (train=0.874, test=0.826) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20; average_precision: (train=0.879, test=0.829) f1: (train=0.761, test=0.727) precision: (train=0.839, test=0.801) recall: (train=0.697, test=0.665) roc_auc: (train=0.872, test=0.829) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20; average_precision: (train=0.884, test=0.823) f1: (train=0.773, test=0.729) precision: (train=0.840, test=0.782) recall: (train=0.717, test=0.684) roc_auc: (train=0.876, test=0.820) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; average_precision: (train=0.885, test=0.833) f1: (train=0.764, test=0.723) precision: (train=0.840, test=0.792) recall: (train=0.701, test=0.665) roc_auc: (train=0.876, test=0.827) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; average_precision: (train=0.885, test=0.832) f1: (train=0.765, test=0.729) precision: (train=0.845, test=0.804) recall: (train=0.698, test=0.667) roc_auc: (train=0.877, test=0.833) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; average_precision: (train=0.888, test=0.828) f1: (train=0.775, test=0.727) precision: (train=0.844, test=0.783) recall: (train=0.717, test=0.678) roc_auc: (train=0.879, test=0.823) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; average_precision: (train=0.886, test=0.833) f1: (train=0.765, test=0.724) precision: (train=0.841, test=0.793) recall: (train=0.701, test=0.666) roc_auc: (train=0.877, test=0.828) total time=   0.5s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; average_precision: (train=0.885, test=0.834) f1: (train=0.766, test=0.733) precision: (train=0.842, test=0.804) recall: (train=0.702, test=0.673) roc_auc: (train=0.877, test=0.834) total time=   0.5s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; average_precision: (train=0.889, test=0.830) f1: (train=0.775, test=0.729) precision: (train=0.845, test=0.786) recall: (train=0.715, test=0.679) roc_auc: (train=0.879, test=0.823) total time=   0.5s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; average_precision: (train=0.888, test=0.834) f1: (train=0.769, test=0.725) precision: (train=0.841, test=0.792) recall: (train=0.709, test=0.669) roc_auc: (train=0.879, test=0.829) total time=   1.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; average_precision: (train=0.887, test=0.834) f1: (train=0.766, test=0.734) precision: (train=0.842, test=0.804) recall: (train=0.703, test=0.675) roc_auc: (train=0.879, test=0.835) total time=   1.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; average_precision: (train=0.890, test=0.830) f1: (train=0.774, test=0.728) precision: (train=0.843, test=0.783) recall: (train=0.715, test=0.681) roc_auc: (train=0.880, test=0.824) total time=   1.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10; average_precision: (train=0.873, test=0.820) f1: (train=0.763, test=0.718) precision: (train=0.826, test=0.773) recall: (train=0.710, test=0.670) roc_auc: (train=0.867, test=0.817) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10; average_precision: (train=0.873, test=0.823) f1: (train=0.762, test=0.723) precision: (train=0.829, test=0.791) recall: (train=0.705, test=0.666) roc_auc: (train=0.867, test=0.823) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10; average_precision: (train=0.876, test=0.817) f1: (train=0.765, test=0.720) precision: (train=0.833, test=0.771) recall: (train=0.707, test=0.675) roc_auc: (train=0.868, test=0.815) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=12; average_precision: (train=0.875, test=0.821) f1: (train=0.764, test=0.720) precision: (train=0.831, test=0.780) recall: (train=0.707, test=0.668) roc_auc: (train=0.868, test=0.818) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=12; average_precision: (train=0.875, test=0.826) f1: (train=0.761, test=0.723) precision: (train=0.831, test=0.792) recall: (train=0.702, test=0.666) roc_auc: (train=0.869, test=0.825) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=12; average_precision: (train=0.877, test=0.819) f1: (train=0.767, test=0.724) precision: (train=0.835, test=0.773) recall: (train=0.709, test=0.680) roc_auc: (train=0.869, test=0.815) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=14; average_precision: (train=0.877, test=0.823) f1: (train=0.765, test=0.718) precision: (train=0.833, test=0.779) recall: (train=0.707, test=0.666) roc_auc: (train=0.870, test=0.820) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=14; average_precision: (train=0.877, test=0.827) f1: (train=0.762, test=0.725) precision: (train=0.831, test=0.793) recall: (train=0.704, test=0.668) roc_auc: (train=0.870, test=0.827) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=14; average_precision: (train=0.879, test=0.821) f1: (train=0.772, test=0.727) precision: (train=0.839, test=0.776) recall: (train=0.715, test=0.683) roc_auc: (train=0.871, test=0.817) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=16; average_precision: (train=0.878, test=0.823) f1: (train=0.763, test=0.716) precision: (train=0.834, test=0.779) recall: (train=0.703, test=0.662) roc_auc: (train=0.870, test=0.820) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=16; average_precision: (train=0.878, test=0.827) f1: (train=0.764, test=0.726) precision: (train=0.834, test=0.794) recall: (train=0.705, test=0.669) roc_auc: (train=0.871, test=0.828) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=16; average_precision: (train=0.880, test=0.823) f1: (train=0.773, test=0.729) precision: (train=0.839, test=0.780) recall: (train=0.717, test=0.685) roc_auc: (train=0.872, test=0.818) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=18; average_precision: (train=0.878, test=0.825) f1: (train=0.765, test=0.719) precision: (train=0.835, test=0.782) recall: (train=0.706, test=0.665) roc_auc: (train=0.872, test=0.822) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=18; average_precision: (train=0.878, test=0.828) f1: (train=0.765, test=0.727) precision: (train=0.834, test=0.794) recall: (train=0.707, test=0.670) roc_auc: (train=0.872, test=0.829) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=18; average_precision: (train=0.881, test=0.823) f1: (train=0.774, test=0.729) precision: (train=0.841, test=0.780) recall: (train=0.717, test=0.685) roc_auc: (train=0.873, test=0.818) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=20; average_precision: (train=0.880, test=0.825) f1: (train=0.765, test=0.721) precision: (train=0.836, test=0.786) recall: (train=0.706, test=0.665) roc_auc: (train=0.874, test=0.823) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=20; average_precision: (train=0.879, test=0.829) f1: (train=0.763, test=0.729) precision: (train=0.834, test=0.797) recall: (train=0.703, test=0.671) roc_auc: (train=0.873, test=0.830) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=20; average_precision: (train=0.882, test=0.825) f1: (train=0.775, test=0.731) precision: (train=0.843, test=0.784) recall: (train=0.718, test=0.685) roc_auc: (train=0.875, test=0.820) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; average_precision: (train=0.882, test=0.829) f1: (train=0.762, test=0.723) precision: (train=0.836, test=0.791) recall: (train=0.700, test=0.666) roc_auc: (train=0.875, test=0.825) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; average_precision: (train=0.883, test=0.831) f1: (train=0.764, test=0.729) precision: (train=0.840, test=0.799) recall: (train=0.701, test=0.670) roc_auc: (train=0.875, test=0.833) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; average_precision: (train=0.886, test=0.827) f1: (train=0.775, test=0.730) precision: (train=0.843, test=0.786) recall: (train=0.717, test=0.682) roc_auc: (train=0.878, test=0.822) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; average_precision: (train=0.883, test=0.830) f1: (train=0.763, test=0.722) precision: (train=0.837, test=0.792) recall: (train=0.702, test=0.663) roc_auc: (train=0.876, test=0.826) total time=   0.5s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; average_precision: (train=0.884, test=0.833) f1: (train=0.765, test=0.731) precision: (train=0.839, test=0.801) recall: (train=0.702, test=0.672) roc_auc: (train=0.877, test=0.835) total time=   0.5s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; average_precision: (train=0.886, test=0.828) f1: (train=0.774, test=0.729) precision: (train=0.843, test=0.784) recall: (train=0.715, test=0.682) roc_auc: (train=0.878, test=0.822) total time=   0.5s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; average_precision: (train=0.885, test=0.832) f1: (train=0.765, test=0.725) precision: (train=0.838, test=0.793) recall: (train=0.704, test=0.668) roc_auc: (train=0.877, test=0.827) total time=   0.9s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; average_precision: (train=0.884, test=0.834) f1: (train=0.765, test=0.733) precision: (train=0.840, test=0.802) recall: (train=0.702, test=0.675) roc_auc: (train=0.877, test=0.834) total time=   0.9s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; average_precision: (train=0.886, test=0.829) f1: (train=0.775, test=0.730) precision: (train=0.841, test=0.783) recall: (train=0.718, test=0.684) roc_auc: (train=0.878, test=0.823) total time=   0.9s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=10; average_precision: (train=0.866, test=0.816) f1: (train=0.756, test=0.715) precision: (train=0.822, test=0.778) recall: (train=0.700, test=0.662) roc_auc: (train=0.858, test=0.813) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=10; average_precision: (train=0.868, test=0.819) f1: (train=0.751, test=0.721) precision: (train=0.825, test=0.791) recall: (train=0.689, test=0.663) roc_auc: (train=0.860, test=0.821) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=10; average_precision: (train=0.872, test=0.816) f1: (train=0.761, test=0.718) precision: (train=0.826, test=0.772) recall: (train=0.705, test=0.672) roc_auc: (train=0.864, test=0.812) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=12; average_precision: (train=0.868, test=0.818) f1: (train=0.754, test=0.715) precision: (train=0.825, test=0.779) recall: (train=0.695, test=0.660) roc_auc: (train=0.860, test=0.815) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=12; average_precision: (train=0.869, test=0.820) f1: (train=0.752, test=0.721) precision: (train=0.826, test=0.793) recall: (train=0.690, test=0.660) roc_auc: (train=0.861, test=0.822) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=12; average_precision: (train=0.874, test=0.818) f1: (train=0.762, test=0.723) precision: (train=0.827, test=0.776) recall: (train=0.707, test=0.678) roc_auc: (train=0.867, test=0.813) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=14; average_precision: (train=0.870, test=0.820) f1: (train=0.760, test=0.719) precision: (train=0.827, test=0.782) recall: (train=0.703, test=0.666) roc_auc: (train=0.863, test=0.817) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=14; average_precision: (train=0.870, test=0.820) f1: (train=0.751, test=0.721) precision: (train=0.826, test=0.793) recall: (train=0.689, test=0.660) roc_auc: (train=0.861, test=0.822) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=14; average_precision: (train=0.876, test=0.819) f1: (train=0.764, test=0.721) precision: (train=0.831, test=0.777) recall: (train=0.707, test=0.674) roc_auc: (train=0.869, test=0.816) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=16; average_precision: (train=0.870, test=0.820) f1: (train=0.758, test=0.719) precision: (train=0.827, test=0.781) recall: (train=0.699, test=0.667) roc_auc: (train=0.863, test=0.819) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=16; average_precision: (train=0.871, test=0.821) f1: (train=0.753, test=0.723) precision: (train=0.828, test=0.793) recall: (train=0.690, test=0.664) roc_auc: (train=0.862, test=0.823) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=16; average_precision: (train=0.877, test=0.820) f1: (train=0.765, test=0.720) precision: (train=0.833, test=0.775) recall: (train=0.707, test=0.672) roc_auc: (train=0.870, test=0.817) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=18; average_precision: (train=0.872, test=0.821) f1: (train=0.759, test=0.720) precision: (train=0.829, test=0.783) recall: (train=0.701, test=0.667) roc_auc: (train=0.866, test=0.820) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=18; average_precision: (train=0.872, test=0.822) f1: (train=0.755, test=0.723) precision: (train=0.829, test=0.794) recall: (train=0.693, test=0.664) roc_auc: (train=0.864, test=0.824) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=18; average_precision: (train=0.878, test=0.822) f1: (train=0.766, test=0.723) precision: (train=0.834, test=0.779) recall: (train=0.708, test=0.674) roc_auc: (train=0.870, test=0.818) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=20; average_precision: (train=0.874, test=0.823) f1: (train=0.763, test=0.723) precision: (train=0.830, test=0.783) recall: (train=0.706, test=0.671) roc_auc: (train=0.868, test=0.822) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=20; average_precision: (train=0.873, test=0.823) f1: (train=0.756, test=0.723) precision: (train=0.830, test=0.795) recall: (train=0.694, test=0.664) roc_auc: (train=0.866, test=0.826) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=20; average_precision: (train=0.878, test=0.822) f1: (train=0.766, test=0.723) precision: (train=0.834, test=0.780) recall: (train=0.708, test=0.674) roc_auc: (train=0.871, test=0.818) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; average_precision: (train=0.877, test=0.827) f1: (train=0.762, test=0.723) precision: (train=0.832, test=0.790) recall: (train=0.702, test=0.666) roc_auc: (train=0.870, test=0.823) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; average_precision: (train=0.876, test=0.826) f1: (train=0.756, test=0.726) precision: (train=0.835, test=0.799) recall: (train=0.691, test=0.665) roc_auc: (train=0.869, test=0.829) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; average_precision: (train=0.881, test=0.825) f1: (train=0.771, test=0.728) precision: (train=0.838, test=0.785) recall: (train=0.713, test=0.679) roc_auc: (train=0.874, test=0.821) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; average_precision: (train=0.878, test=0.828) f1: (train=0.759, test=0.721) precision: (train=0.832, test=0.790) recall: (train=0.698, test=0.663) roc_auc: (train=0.872, test=0.825) total time=   0.5s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; average_precision: (train=0.878, test=0.828) f1: (train=0.755, test=0.725) precision: (train=0.833, test=0.798) recall: (train=0.691, test=0.665) roc_auc: (train=0.871, test=0.831) total time=   0.5s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; average_precision: (train=0.881, test=0.826) f1: (train=0.770, test=0.727) precision: (train=0.838, test=0.785) recall: (train=0.711, test=0.678) roc_auc: (train=0.874, test=0.821) total time=   0.5s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; average_precision: (train=0.880, test=0.829) f1: (train=0.762, test=0.721) precision: (train=0.833, test=0.789) recall: (train=0.701, test=0.664) roc_auc: (train=0.873, test=0.825) total time=   0.9s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; average_precision: (train=0.879, test=0.830) f1: (train=0.759, test=0.729) precision: (train=0.834, test=0.800) recall: (train=0.696, test=0.669) roc_auc: (train=0.872, test=0.832) total time=   0.9s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; average_precision: (train=0.882, test=0.827) f1: (train=0.770, test=0.727) precision: (train=0.836, test=0.783) recall: (train=0.713, test=0.679) roc_auc: (train=0.874, test=0.821) total time=   0.9s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10; average_precision: (train=0.873, test=0.817) f1: (train=0.757, test=0.717) precision: (train=0.823, test=0.775) recall: (train=0.701, test=0.667) roc_auc: (train=0.865, test=0.817) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10; average_precision: (train=0.873, test=0.822) f1: (train=0.757, test=0.721) precision: (train=0.830, test=0.793) recall: (train=0.695, test=0.661) roc_auc: (train=0.865, test=0.822) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10; average_precision: (train=0.876, test=0.819) f1: (train=0.766, test=0.724) precision: (train=0.828, test=0.771) recall: (train=0.713, test=0.682) roc_auc: (train=0.867, test=0.814) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=12; average_precision: (train=0.875, test=0.822) f1: (train=0.759, test=0.716) precision: (train=0.829, test=0.779) recall: (train=0.700, test=0.662) roc_auc: (train=0.868, test=0.819) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=12; average_precision: (train=0.875, test=0.823) f1: (train=0.760, test=0.723) precision: (train=0.836, test=0.796) recall: (train=0.697, test=0.662) roc_auc: (train=0.868, test=0.825) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=12; average_precision: (train=0.877, test=0.821) f1: (train=0.769, test=0.726) precision: (train=0.831, test=0.772) recall: (train=0.716, test=0.685) roc_auc: (train=0.869, test=0.815) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=14; average_precision: (train=0.877, test=0.824) f1: (train=0.760, test=0.717) precision: (train=0.831, test=0.780) recall: (train=0.700, test=0.663) roc_auc: (train=0.870, test=0.821) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=14; average_precision: (train=0.876, test=0.823) f1: (train=0.760, test=0.723) precision: (train=0.838, test=0.795) recall: (train=0.695, test=0.662) roc_auc: (train=0.869, test=0.826) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=14; average_precision: (train=0.881, test=0.822) f1: (train=0.771, test=0.727) precision: (train=0.834, test=0.774) recall: (train=0.717, test=0.685) roc_auc: (train=0.872, test=0.818) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=16; average_precision: (train=0.878, test=0.825) f1: (train=0.760, test=0.718) precision: (train=0.832, test=0.785) recall: (train=0.699, test=0.662) roc_auc: (train=0.871, test=0.822) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=16; average_precision: (train=0.876, test=0.824) f1: (train=0.760, test=0.724) precision: (train=0.836, test=0.797) recall: (train=0.697, test=0.663) roc_auc: (train=0.869, test=0.827) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=16; average_precision: (train=0.881, test=0.822) f1: (train=0.771, test=0.726) precision: (train=0.834, test=0.773) recall: (train=0.716, test=0.685) roc_auc: (train=0.873, test=0.818) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=18; average_precision: (train=0.879, test=0.826) f1: (train=0.762, test=0.720) precision: (train=0.834, test=0.786) recall: (train=0.701, test=0.664) roc_auc: (train=0.872, test=0.823) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=18; average_precision: (train=0.878, test=0.826) f1: (train=0.758, test=0.725) precision: (train=0.836, test=0.800) recall: (train=0.693, test=0.663) roc_auc: (train=0.872, test=0.829) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=18; average_precision: (train=0.883, test=0.823) f1: (train=0.773, test=0.726) precision: (train=0.834, test=0.773) recall: (train=0.719, test=0.684) roc_auc: (train=0.875, test=0.819) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=20; average_precision: (train=0.879, test=0.826) f1: (train=0.765, test=0.723) precision: (train=0.835, test=0.787) recall: (train=0.706, test=0.668) roc_auc: (train=0.873, test=0.824) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=20; average_precision: (train=0.878, test=0.827) f1: (train=0.760, test=0.727) precision: (train=0.838, test=0.803) recall: (train=0.695, test=0.664) roc_auc: (train=0.872, test=0.829) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=20; average_precision: (train=0.883, test=0.823) f1: (train=0.771, test=0.724) precision: (train=0.835, test=0.773) recall: (train=0.716, test=0.680) roc_auc: (train=0.875, test=0.819) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; average_precision: (train=0.884, test=0.830) f1: (train=0.760, test=0.717) precision: (train=0.837, test=0.788) recall: (train=0.696, test=0.658) roc_auc: (train=0.875, test=0.826) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; average_precision: (train=0.882, test=0.829) f1: (train=0.761, test=0.728) precision: (train=0.840, test=0.801) recall: (train=0.695, test=0.666) roc_auc: (train=0.873, test=0.830) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; average_precision: (train=0.886, test=0.826) f1: (train=0.774, test=0.729) precision: (train=0.840, test=0.782) recall: (train=0.717, test=0.682) roc_auc: (train=0.877, test=0.821) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; average_precision: (train=0.884, test=0.831) f1: (train=0.760, test=0.719) precision: (train=0.838, test=0.790) recall: (train=0.696, test=0.660) roc_auc: (train=0.875, test=0.826) total time=   0.5s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; average_precision: (train=0.884, test=0.832) f1: (train=0.761, test=0.730) precision: (train=0.838, test=0.801) recall: (train=0.697, test=0.670) roc_auc: (train=0.876, test=0.833) total time=   0.5s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; average_precision: (train=0.886, test=0.827) f1: (train=0.770, test=0.726) precision: (train=0.839, test=0.781) recall: (train=0.712, test=0.677) roc_auc: (train=0.876, test=0.821) total time=   0.5s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; average_precision: (train=0.886, test=0.832) f1: (train=0.763, test=0.722) precision: (train=0.838, test=0.792) recall: (train=0.700, test=0.663) roc_auc: (train=0.877, test=0.827) total time=   0.9s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; average_precision: (train=0.885, test=0.834) f1: (train=0.763, test=0.733) precision: (train=0.839, test=0.803) recall: (train=0.699, test=0.674) roc_auc: (train=0.877, test=0.834) total time=   0.9s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; average_precision: (train=0.887, test=0.829) f1: (train=0.771, test=0.727) precision: (train=0.839, test=0.782) recall: (train=0.713, test=0.679) roc_auc: (train=0.877, test=0.822) total time=   0.9s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; average_precision: (train=0.875, test=0.821) f1: (train=0.761, test=0.717) precision: (train=0.823, test=0.771) recall: (train=0.707, test=0.670) roc_auc: (train=0.867, test=0.818) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; average_precision: (train=0.872, test=0.821) f1: (train=0.762, test=0.727) precision: (train=0.825, test=0.790) recall: (train=0.708, test=0.674) roc_auc: (train=0.864, test=0.823) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; average_precision: (train=0.878, test=0.818) f1: (train=0.770, test=0.725) precision: (train=0.833, test=0.774) recall: (train=0.716, test=0.682) roc_auc: (train=0.869, test=0.814) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=12; average_precision: (train=0.876, test=0.823) f1: (train=0.761, test=0.716) precision: (train=0.827, test=0.775) recall: (train=0.704, test=0.666) roc_auc: (train=0.868, test=0.820) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=12; average_precision: (train=0.873, test=0.822) f1: (train=0.759, test=0.725) precision: (train=0.830, test=0.795) recall: (train=0.699, test=0.667) roc_auc: (train=0.865, test=0.824) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=12; average_precision: (train=0.879, test=0.820) f1: (train=0.769, test=0.723) precision: (train=0.834, test=0.775) recall: (train=0.713, test=0.676) roc_auc: (train=0.870, test=0.815) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=14; average_precision: (train=0.878, test=0.824) f1: (train=0.761, test=0.718) precision: (train=0.829, test=0.777) recall: (train=0.704, test=0.668) roc_auc: (train=0.869, test=0.820) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=14; average_precision: (train=0.875, test=0.824) f1: (train=0.760, test=0.725) precision: (train=0.833, test=0.793) recall: (train=0.699, test=0.668) roc_auc: (train=0.866, test=0.825) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=14; average_precision: (train=0.880, test=0.820) f1: (train=0.772, test=0.724) precision: (train=0.836, test=0.777) recall: (train=0.717, test=0.679) roc_auc: (train=0.872, test=0.817) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=16; average_precision: (train=0.879, test=0.825) f1: (train=0.763, test=0.718) precision: (train=0.833, test=0.779) recall: (train=0.704, test=0.666) roc_auc: (train=0.870, test=0.821) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=16; average_precision: (train=0.876, test=0.825) f1: (train=0.759, test=0.725) precision: (train=0.831, test=0.795) recall: (train=0.698, test=0.666) roc_auc: (train=0.867, test=0.826) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=16; average_precision: (train=0.881, test=0.822) f1: (train=0.773, test=0.726) precision: (train=0.837, test=0.779) recall: (train=0.718, test=0.680) roc_auc: (train=0.873, test=0.818) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=18; average_precision: (train=0.879, test=0.826) f1: (train=0.764, test=0.719) precision: (train=0.834, test=0.781) recall: (train=0.705, test=0.666) roc_auc: (train=0.871, test=0.822) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=18; average_precision: (train=0.878, test=0.825) f1: (train=0.759, test=0.725) precision: (train=0.834, test=0.798) recall: (train=0.696, test=0.665) roc_auc: (train=0.870, test=0.828) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=18; average_precision: (train=0.882, test=0.822) f1: (train=0.774, test=0.728) precision: (train=0.839, test=0.782) recall: (train=0.718, test=0.681) roc_auc: (train=0.875, test=0.819) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=20; average_precision: (train=0.881, test=0.827) f1: (train=0.765, test=0.721) precision: (train=0.835, test=0.783) recall: (train=0.706, test=0.668) roc_auc: (train=0.873, test=0.824) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=20; average_precision: (train=0.879, test=0.826) f1: (train=0.758, test=0.725) precision: (train=0.835, test=0.797) recall: (train=0.695, test=0.664) roc_auc: (train=0.870, test=0.829) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=20; average_precision: (train=0.882, test=0.822) f1: (train=0.772, test=0.727) precision: (train=0.839, test=0.782) recall: (train=0.715, test=0.679) roc_auc: (train=0.875, test=0.819) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; average_precision: (train=0.882, test=0.828) f1: (train=0.765, test=0.720) precision: (train=0.838, test=0.790) recall: (train=0.703, test=0.661) roc_auc: (train=0.873, test=0.824) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; average_precision: (train=0.882, test=0.830) f1: (train=0.758, test=0.726) precision: (train=0.838, test=0.803) recall: (train=0.692, test=0.662) roc_auc: (train=0.873, test=0.831) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; average_precision: (train=0.886, test=0.825) f1: (train=0.772, test=0.726) precision: (train=0.842, test=0.783) recall: (train=0.713, test=0.677) roc_auc: (train=0.877, test=0.820) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; average_precision: (train=0.883, test=0.831) f1: (train=0.761, test=0.719) precision: (train=0.836, test=0.790) recall: (train=0.699, test=0.660) roc_auc: (train=0.874, test=0.825) total time=   0.5s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; average_precision: (train=0.883, test=0.831) f1: (train=0.760, test=0.728) precision: (train=0.838, test=0.801) recall: (train=0.695, test=0.667) roc_auc: (train=0.875, test=0.833) total time=   0.5s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; average_precision: (train=0.886, test=0.825) f1: (train=0.771, test=0.726) precision: (train=0.840, test=0.783) recall: (train=0.713, test=0.677) roc_auc: (train=0.876, test=0.820) total time=   0.5s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; average_precision: (train=0.885, test=0.831) f1: (train=0.763, test=0.720) precision: (train=0.837, test=0.791) recall: (train=0.701, test=0.661) roc_auc: (train=0.876, test=0.827) total time=   0.9s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; average_precision: (train=0.883, test=0.832) f1: (train=0.762, test=0.729) precision: (train=0.837, test=0.801) recall: (train=0.700, test=0.669) roc_auc: (train=0.875, test=0.834) total time=   0.9s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; average_precision: (train=0.887, test=0.827) f1: (train=0.773, test=0.730) precision: (train=0.840, test=0.784) recall: (train=0.715, test=0.682) roc_auc: (train=0.877, test=0.821) total time=   0.9s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=10; average_precision: (train=0.870, test=0.819) f1: (train=0.757, test=0.715) precision: (train=0.822, test=0.777) recall: (train=0.701, test=0.662) roc_auc: (train=0.861, test=0.815) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=10; average_precision: (train=0.865, test=0.817) f1: (train=0.751, test=0.718) precision: (train=0.821, test=0.786) recall: (train=0.691, test=0.661) roc_auc: (train=0.856, test=0.818) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=10; average_precision: (train=0.872, test=0.815) f1: (train=0.765, test=0.721) precision: (train=0.828, test=0.771) recall: (train=0.710, test=0.677) roc_auc: (train=0.865, test=0.814) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=12; average_precision: (train=0.871, test=0.821) f1: (train=0.758, test=0.715) precision: (train=0.828, test=0.782) recall: (train=0.699, test=0.658) roc_auc: (train=0.863, test=0.817) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=12; average_precision: (train=0.868, test=0.819) f1: (train=0.750, test=0.719) precision: (train=0.823, test=0.790) recall: (train=0.689, test=0.660) roc_auc: (train=0.859, test=0.821) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=12; average_precision: (train=0.875, test=0.817) f1: (train=0.766, test=0.723) precision: (train=0.829, test=0.772) recall: (train=0.712, test=0.679) roc_auc: (train=0.868, test=0.815) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=14; average_precision: (train=0.873, test=0.823) f1: (train=0.760, test=0.718) precision: (train=0.831, test=0.786) recall: (train=0.699, test=0.661) roc_auc: (train=0.864, test=0.818) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=14; average_precision: (train=0.870, test=0.821) f1: (train=0.752, test=0.721) precision: (train=0.826, test=0.792) recall: (train=0.690, test=0.662) roc_auc: (train=0.861, test=0.823) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=14; average_precision: (train=0.876, test=0.818) f1: (train=0.766, test=0.723) precision: (train=0.830, test=0.774) recall: (train=0.711, test=0.679) roc_auc: (train=0.869, test=0.816) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=16; average_precision: (train=0.874, test=0.824) f1: (train=0.760, test=0.717) precision: (train=0.833, test=0.787) recall: (train=0.699, test=0.658) roc_auc: (train=0.866, test=0.820) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=16; average_precision: (train=0.871, test=0.823) f1: (train=0.753, test=0.722) precision: (train=0.827, test=0.794) recall: (train=0.692, test=0.662) roc_auc: (train=0.862, test=0.824) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=16; average_precision: (train=0.877, test=0.820) f1: (train=0.768, test=0.725) precision: (train=0.832, test=0.776) recall: (train=0.713, test=0.681) roc_auc: (train=0.870, test=0.817) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=18; average_precision: (train=0.874, test=0.824) f1: (train=0.762, test=0.718) precision: (train=0.833, test=0.788) recall: (train=0.702, test=0.659) roc_auc: (train=0.867, test=0.821) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=18; average_precision: (train=0.871, test=0.824) f1: (train=0.754, test=0.723) precision: (train=0.828, test=0.796) recall: (train=0.692, test=0.663) roc_auc: (train=0.864, test=0.825) total time=   0.1s
# ...
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=12; average_precision: (train=0.990, test=0.907) f1: (train=0.950, test=0.854) precision: (train=0.939, test=0.832) recall: (train=0.961, test=0.877) roc_auc: (train=0.990, test=0.915) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=14; average_precision: (train=0.991, test=0.912) f1: (train=0.950, test=0.854) precision: (train=0.939, test=0.832) recall: (train=0.962, test=0.877) roc_auc: (train=0.991, test=0.919) total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=14; average_precision: (train=0.991, test=0.918) f1: (train=0.949, test=0.862) precision: (train=0.936, test=0.850) recall: (train=0.962, test=0.875) roc_auc: (train=0.991, test=0.923) total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=14; average_precision: (train=0.991, test=0.909) f1: (train=0.951, test=0.854) precision: (train=0.940, test=0.832) recall: (train=0.963, test=0.877) roc_auc: (train=0.991, test=0.917) total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=16; average_precision: (train=0.992, test=0.914) f1: (train=0.952, test=0.858) precision: (train=0.941, test=0.836) recall: (train=0.963, test=0.881) roc_auc: (train=0.992, test=0.921) total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=16; average_precision: (train=0.992, test=0.919) f1: (train=0.951, test=0.865) precision: (train=0.938, test=0.851) recall: (train=0.966, test=0.879) roc_auc: (train=0.992, test=0.924) total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=16; average_precision: (train=0.992, test=0.912) f1: (train=0.953, test=0.857) precision: (train=0.942, test=0.839) recall: (train=0.964, test=0.876) roc_auc: (train=0.992, test=0.919) total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=18; average_precision: (train=0.992, test=0.916) f1: (train=0.954, test=0.861) precision: (train=0.942, test=0.839) recall: (train=0.966, test=0.885) roc_auc: (train=0.992, test=0.923) total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=18; average_precision: (train=0.992, test=0.921) f1: (train=0.952, test=0.865) precision: (train=0.938, test=0.854) recall: (train=0.966, test=0.877) roc_auc: (train=0.992, test=0.925) total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=18; average_precision: (train=0.992, test=0.913) f1: (train=0.953, test=0.859) precision: (train=0.942, test=0.841) recall: (train=0.965, test=0.878) roc_auc: (train=0.992, test=0.921) total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=20; average_precision: (train=0.992, test=0.917) f1: (train=0.954, test=0.861) precision: (train=0.942, test=0.840) recall: (train=0.966, test=0.883) roc_auc: (train=0.992, test=0.924) total time=   0.3s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=20; average_precision: (train=0.992, test=0.922) f1: (train=0.953, test=0.866) precision: (train=0.939, test=0.855) recall: (train=0.967, test=0.878) roc_auc: (train=0.992, test=0.926) total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=20; average_precision: (train=0.993, test=0.915) f1: (train=0.954, test=0.860) precision: (train=0.943, test=0.844) recall: (train=0.965, test=0.876) roc_auc: (train=0.993, test=0.922) total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; average_precision: (train=0.994, test=0.923) f1: (train=0.959, test=0.871) precision: (train=0.946, test=0.851) recall: (train=0.972, test=0.891) roc_auc: (train=0.994, test=0.929) total time=   0.6s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; average_precision: (train=0.994, test=0.928) f1: (train=0.957, test=0.873) precision: (train=0.943, test=0.866) recall: (train=0.971, test=0.881) roc_auc: (train=0.994, test=0.932) total time=   0.6s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; average_precision: (train=0.994, test=0.922) f1: (train=0.959, test=0.871) precision: (train=0.946, test=0.855) recall: (train=0.974, test=0.887) roc_auc: (train=0.994, test=0.928) total time=   0.6s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; average_precision: (train=0.995, test=0.925) f1: (train=0.961, test=0.875) precision: (train=0.947, test=0.853) recall: (train=0.976, test=0.897) roc_auc: (train=0.995, test=0.931) total time=   1.1s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; average_precision: (train=0.995, test=0.930) f1: (train=0.959, test=0.876) precision: (train=0.945, test=0.868) recall: (train=0.973, test=0.885) roc_auc: (train=0.995, test=0.934) total time=   1.1s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; average_precision: (train=0.995, test=0.923) f1: (train=0.960, test=0.871) precision: (train=0.946, test=0.855) recall: (train=0.975, test=0.888) roc_auc: (train=0.995, test=0.930) total time=   1.1s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; average_precision: (train=0.995, test=0.926) f1: (train=0.960, test=0.873) precision: (train=0.946, test=0.853) recall: (train=0.975, test=0.893) roc_auc: (train=0.995, test=0.932) total time=   2.2s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; average_precision: (train=0.995, test=0.931) f1: (train=0.958, test=0.876) precision: (train=0.944, test=0.869) recall: (train=0.972, test=0.883) roc_auc: (train=0.995, test=0.935) total time=   2.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; average_precision: (train=0.995, test=0.924) f1: (train=0.961, test=0.873) precision: (train=0.947, test=0.856) recall: (train=0.976, test=0.891) roc_auc: (train=0.995, test=0.931) total time=   2.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=10; average_precision: (train=0.987, test=0.902) f1: (train=0.942, test=0.847) precision: (train=0.932, test=0.828) recall: (train=0.953, test=0.868) roc_auc: (train=0.987, test=0.911) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=10; average_precision: (train=0.987, test=0.908) f1: (train=0.940, test=0.853) precision: (train=0.929, test=0.841) recall: (train=0.950, test=0.864) roc_auc: (train=0.987, test=0.915) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=10; average_precision: (train=0.988, test=0.900) f1: (train=0.943, test=0.845) precision: (train=0.931, test=0.825) recall: (train=0.955, test=0.867) roc_auc: (train=0.987, test=0.911) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=12; average_precision: (train=0.988, test=0.904) f1: (train=0.944, test=0.850) precision: (train=0.934, test=0.830) recall: (train=0.955, test=0.871) roc_auc: (train=0.988, test=0.913) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=12; average_precision: (train=0.988, test=0.911) f1: (train=0.943, test=0.858) precision: (train=0.932, test=0.848) recall: (train=0.954, test=0.869) roc_auc: (train=0.988, test=0.918) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=12; average_precision: (train=0.989, test=0.905) f1: (train=0.945, test=0.852) precision: (train=0.933, test=0.832) recall: (train=0.958, test=0.873) roc_auc: (train=0.989, test=0.914) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=14; average_precision: (train=0.989, test=0.907) f1: (train=0.947, test=0.850) precision: (train=0.937, test=0.830) recall: (train=0.956, test=0.872) roc_auc: (train=0.989, test=0.916) total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=14; average_precision: (train=0.989, test=0.913) f1: (train=0.945, test=0.859) precision: (train=0.935, test=0.852) recall: (train=0.955, test=0.867) roc_auc: (train=0.989, test=0.920) total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=14; average_precision: (train=0.990, test=0.907) f1: (train=0.948, test=0.853) precision: (train=0.935, test=0.835) recall: (train=0.960, test=0.871) roc_auc: (train=0.990, test=0.916) total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=16; average_precision: (train=0.990, test=0.908) f1: (train=0.948, test=0.852) precision: (train=0.936, test=0.830) recall: (train=0.961, test=0.876) roc_auc: (train=0.990, test=0.917) total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=16; average_precision: (train=0.990, test=0.914) f1: (train=0.948, test=0.863) precision: (train=0.935, test=0.854) recall: (train=0.961, test=0.872) roc_auc: (train=0.990, test=0.922) total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=16; average_precision: (train=0.990, test=0.909) f1: (train=0.949, test=0.855) precision: (train=0.937, test=0.838) recall: (train=0.962, test=0.873) roc_auc: (train=0.990, test=0.918) total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=18; average_precision: (train=0.990, test=0.910) f1: (train=0.950, test=0.857) precision: (train=0.937, test=0.834) recall: (train=0.963, test=0.881) roc_auc: (train=0.990, test=0.919) total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=18; average_precision: (train=0.990, test=0.916) f1: (train=0.949, test=0.866) precision: (train=0.936, test=0.857) recall: (train=0.963, test=0.874) roc_auc: (train=0.990, test=0.924) total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=18; average_precision: (train=0.991, test=0.911) f1: (train=0.949, test=0.856) precision: (train=0.938, test=0.841) recall: (train=0.961, test=0.871) roc_auc: (train=0.991, test=0.919) total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=20; average_precision: (train=0.991, test=0.911) f1: (train=0.950, test=0.858) precision: (train=0.937, test=0.837) recall: (train=0.964, test=0.881) roc_auc: (train=0.991, test=0.920) total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=20; average_precision: (train=0.990, test=0.917) f1: (train=0.949, test=0.864) precision: (train=0.935, test=0.857) recall: (train=0.963, test=0.872) roc_auc: (train=0.991, test=0.924) total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=20; average_precision: (train=0.991, test=0.912) f1: (train=0.950, test=0.857) precision: (train=0.939, test=0.843) recall: (train=0.962, test=0.871) roc_auc: (train=0.991, test=0.920) total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; average_precision: (train=0.992, test=0.917) f1: (train=0.953, test=0.865) precision: (train=0.940, test=0.847) recall: (train=0.967, test=0.883) roc_auc: (train=0.992, test=0.925) total time=   0.6s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; average_precision: (train=0.993, test=0.924) f1: (train=0.953, test=0.871) precision: (train=0.939, test=0.863) recall: (train=0.968, test=0.880) roc_auc: (train=0.993, test=0.930) total time=   0.6s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; average_precision: (train=0.993, test=0.918) f1: (train=0.955, test=0.866) precision: (train=0.941, test=0.853) recall: (train=0.968, test=0.879) roc_auc: (train=0.993, test=0.926) total time=   0.6s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; average_precision: (train=0.993, test=0.921) f1: (train=0.954, test=0.867) precision: (train=0.940, test=0.851) recall: (train=0.969, test=0.884) roc_auc: (train=0.993, test=0.927) total time=   1.1s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; average_precision: (train=0.993, test=0.926) f1: (train=0.954, test=0.871) precision: (train=0.937, test=0.865) recall: (train=0.970, test=0.877) roc_auc: (train=0.993, test=0.932) total time=   1.1s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; average_precision: (train=0.993, test=0.920) f1: (train=0.955, test=0.868) precision: (train=0.941, test=0.855) recall: (train=0.970, test=0.882) roc_auc: (train=0.993, test=0.927) total time=   1.1s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; average_precision: (train=0.993, test=0.922) f1: (train=0.955, test=0.869) precision: (train=0.940, test=0.851) recall: (train=0.970, test=0.887) roc_auc: (train=0.993, test=0.928) total time=   2.2s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; average_precision: (train=0.993, test=0.927) f1: (train=0.954, test=0.872) precision: (train=0.938, test=0.865) recall: (train=0.970, test=0.878) roc_auc: (train=0.993, test=0.932) total time=   2.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; average_precision: (train=0.994, test=0.921) f1: (train=0.957, test=0.870) precision: (train=0.942, test=0.858) recall: (train=0.972, test=0.882) roc_auc: (train=0.994, test=0.928) total time=   2.2s
# Duración búsqueda: 0 days 00:30:37.491113

# %%
start = pd.Timestamp.now()

# Crear el modelo RANDOM FOREST - CV = 10
modeloRF = RandomForestClassifier(
  n_jobs = -1, # Utilizar todos los núcleos disponibles para acelerar el entrenamiento
  random_state = 42, # Semilla para la reproducibilidad de los resultados
  n_estimators=10, # Número de árboles en el bosque aleatorio
  criterion="gini", # Criterio para la selección del umbral de decisión
  max_features="sqrt",
  max_depth=10,
  min_samples_split=2,
  min_samples_leaf=1
  )

train_sizes_10 = [0.2, 0.4, 0.6, 0.8, 0.9, 1]

train_size_abs_10, train_scores_10, test_scores_10 = learning_curve(
    modeloRF, X_resampled, y_resampled, train_sizes=train_sizes_10, scoring='recall',
    cv=10, n_jobs=-1
    #n_jobs=4, pre_dispatch='2*n_jobs'
)

end = pd.Timestamp.now()
print(f"Duración búsqueda: {end-start}")

for train_size, cv_train_scores, cv_test_scores in zip(
    train_size_abs_10, train_scores_10, test_scores_10
):
    print(f"{train_size} samples were used to train the model")
    print(f"The average train accuracy is {cv_train_scores.mean():.2f}")
    print(f"The average test accuracy is {cv_test_scores.mean():.2f}")

# Suponiendo que 'train_size_abs_10' tiene los tamaños absolutos del conjunto de entrenamiento
total_data_size = max(train_size_abs_10)  # El tamaño total del conjunto de datos

# Convertir los tamaños de entrenamiento a porcentaje
train_size_pct_10 = (train_size_abs_10 / total_data_size) * 100

# Calcular los promedios y desviaciones estándar (ya lo tienes)
train_mean_10 = np.mean(train_scores_10, axis=1)
train_std_10 = np.std(train_scores_10, axis=1)
test_mean_10 = np.mean(test_scores_10, axis=1)
test_std_10 = np.std(test_scores_10, axis=1)

# Graficar la curva de aprendizaje
plt.plot(train_size_pct_10, train_mean_10, color='#FF7B00', marker='o', markersize=5, label='Training Recall')
plt.fill_between(train_size_pct_10, train_mean_10 + train_std_10, train_mean_10 - train_std_10, alpha=0.15, color='#FF7B00')

plt.plot(train_size_pct_10, test_mean_10, color='#8B4513', marker='+', markersize=5, linestyle='--', label='Validation Recall')
plt.fill_between(train_size_pct_10, test_mean_10 + test_std_10, test_mean_10 - test_std_10, alpha=0.15, color='#8B4513')

# Personalización del gráfico
plt.title('Learning Curve ROS, combinación 75%')
plt.xlabel('Training Data Size (%)')  # Cambiar la etiqueta del eje x
plt.ylabel('Model Recall')
plt.ylim(0, 1)
plt.grid()
plt.legend(loc='lower right')

# Mostrar el gráfico
plt.show()
# Out:
# Duración búsqueda: 0 days 00:00:05.000808
# 8411 samples were used to train the model
# The average train accuracy is 0.44
# The average test accuracy is 0.33
# 16822 samples were used to train the model
# The average train accuracy is 0.44
# The average test accuracy is 0.37
# 25233 samples were used to train the model
# The average train accuracy is 0.43
# The average test accuracy is 0.40
# 33644 samples were used to train the model
# The average train accuracy is 0.57
# The average test accuracy is 0.55
# 37849 samples were used to train the model
# The average train accuracy is 0.65
# The average test accuracy is 0.62
# 42055 samples were used to train the model
# The average train accuracy is 0.70
# The average test accuracy is 0.68

# %%
# ENTRENAR MEJORES MODELOS

# DF CON TRAIN_SIZE=0.75

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, train_size=0.75, random_state=42)

#Medir tiempo de ejecución
start = pd.Timestamp.now()

# Crear el mejor modelo
best_rf_75 = RandomForestClassifier(
    n_estimators=10,               # Número de árboles en el bosque
    criterion="gini",          # Criterio para la división de nodos ('entropy' para la ganancia de información)
    max_features="sqrt",          # Número de características a considerar en cada división ('sqrt' para la raíz cuadrada del número total de características)}
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=1,
    n_jobs = -1,
    random_state = 42
)

# Ajustar modelo
fit_75 = best_rf_75.fit(X_train, y_train)

#Medir tiempo de ejecución
end = pd.Timestamp.now()
print(f"Duración búsqueda: {end-start}")

# Matriz de confusión para model_grid.best_params_
y_pred = fit_75.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# Crear la visualización de la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['PAGO', 'NO PAGO'])

# Graficar la matriz de confusión con un título
fig, ax = plt.subplots(figsize=(8, 6))  # Configurar el tamaño del gráfico
disp.plot(cmap="Blues", ax=ax)  # Asociar la visualización con los ejes del gráfico
ax.set_title("Matriz de Confusión - Mejor Modelo Random Forest ROS (75%)", fontsize=16)

# Mostrar el gráfico
plt.show()
# Out:
# Duración búsqueda: 0 days 00:00:00.116688

# %%
start = pd.Timestamp.now()

# Crear el modelo RANDOM FOREST - CV = 10
modeloRF = RandomForestClassifier(
  n_jobs = -1, # Utilizar todos los núcleos disponibles para acelerar el entrenamiento
  random_state = 42, # Semilla para la reproducibilidad de los resultados
  n_estimators=200, # Número de árboles en el bosque aleatorio
  criterion="entropy", # Criterio para la selección del umbral de decisión
  max_features="sqrt",
  max_depth=30,
  min_samples_split=2,
  min_samples_leaf=2
  )

train_sizes_10 = [0.2, 0.4, 0.6, 0.8, 0.9, 1]

train_size_abs_10, train_scores_10, test_scores_10 = learning_curve(
    modeloRF, X_resampled, y_resampled, train_sizes=train_sizes_10, scoring='recall',
    cv=10, n_jobs=-1
    #n_jobs=4, pre_dispatch='2*n_jobs'
)

end = pd.Timestamp.now()
print(f"Duración búsqueda: {end-start}")

for train_size, cv_train_scores, cv_test_scores in zip(
    train_size_abs_10, train_scores_10, test_scores_10
):
    print(f"{train_size} samples were used to train the model")
    print(f"The average train accuracy is {cv_train_scores.mean():.2f}")
    print(f"The average test accuracy is {cv_test_scores.mean():.2f}")

# Suponiendo que 'train_size_abs_10' tiene los tamaños absolutos del conjunto de entrenamiento
total_data_size = max(train_size_abs_10)  # El tamaño total del conjunto de datos

# Convertir los tamaños de entrenamiento a porcentaje
train_size_pct_10 = (train_size_abs_10 / total_data_size) * 100

# Calcular los promedios y desviaciones estándar (ya lo tienes)
train_mean_10 = np.mean(train_scores_10, axis=1)
train_std_10 = np.std(train_scores_10, axis=1)
test_mean_10 = np.mean(test_scores_10, axis=1)
test_std_10 = np.std(test_scores_10, axis=1)

# Graficar la curva de aprendizaje
plt.plot(train_size_pct_10, train_mean_10, color='#FF7B00', marker='o', markersize=5, label='Training Recall')
plt.fill_between(train_size_pct_10, train_mean_10 + train_std_10, train_mean_10 - train_std_10, alpha=0.15, color='#FF7B00')

plt.plot(train_size_pct_10, test_mean_10, color='#8B4513', marker='+', markersize=5, linestyle='--', label='Validation Recall')
plt.fill_between(train_size_pct_10, test_mean_10 + test_std_10, test_mean_10 - test_std_10, alpha=0.15, color='#8B4513')

# Personalización del gráfico
plt.title('Learning Curve ROS, combinación 80%')
plt.xlabel('Training Data Size (%)')  # Cambiar la etiqueta del eje x
plt.ylabel('Model Recall')
plt.ylim(0, 1)
plt.grid()
plt.legend(loc='lower right')

# Mostrar el gráfico
plt.show()
# Out:
# Duración búsqueda: 0 days 00:02:38.922566
# 8411 samples were used to train the model
# The average train accuracy is 0.89
# The average test accuracy is 0.45
# 16822 samples were used to train the model
# The average train accuracy is 0.90
# The average test accuracy is 0.59
# 25233 samples were used to train the model
# The average train accuracy is 0.89
# The average test accuracy is 0.70
# 33644 samples were used to train the model
# The average train accuracy is 0.98
# The average test accuracy is 0.91
# 37849 samples were used to train the model
# The average train accuracy is 0.99
# The average test accuracy is 0.95
# 42055 samples were used to train the model
# The average train accuracy is 1.00
# The average test accuracy is 0.97

# %%
# ENTRENAR MEJORES MODELOS

# DF CON TRAIN_SIZE=0.80

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, train_size=0.80, random_state=42)

#Medir tiempo de ejecución
start = pd.Timestamp.now()

# Crear el mejor modelo
best_rf_80 = RandomForestClassifier(
    n_estimators=200,               # Número de árboles en el bosque
    criterion="entropy",          # Criterio para la división de nodos ('entropy' para la ganancia de información)
    max_features="sqrt",          # Número de características a considerar en cada división ('sqrt' para la raíz cuadrada del número total de características)}
    max_depth=30,
    min_samples_split=2,
    min_samples_leaf=1,
    n_jobs = -1,
    random_state = 42
)

# Ajustar modelo
fit_80 = best_rf_80.fit(X_train, y_train)

#Medir tiempo de ejecución
end = pd.Timestamp.now()
print(f"Duración búsqueda: {end-start}")

# Matriz de confusión para model_grid.best_params_
y_pred = fit_80.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# Crear la visualización de la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['PAGO', 'NO PAGO'])

# Graficar la matriz de confusión con un título
fig, ax = plt.subplots(figsize=(8, 6))  # Configurar el tamaño del gráfico
disp.plot(cmap="Blues", ax=ax)  # Asociar la visualización con los ejes del gráfico
ax.set_title("Matriz de Confusión - Mejor Modelo Random Forest ROS (80%)", fontsize=16)

# Mostrar el gráfico
plt.show()
# Out:
# Duración búsqueda: 0 days 00:00:03.591396

# %%
start = pd.Timestamp.now()

# Crear el modelo RANDOM FOREST - CV = 10
modeloRF = RandomForestClassifier(
  n_jobs = -1, # Utilizar todos los núcleos disponibles para acelerar el entrenamiento
  random_state = 42, # Semilla para la reproducibilidad de los resultados
  n_estimators=100, # Número de árboles en el bosque aleatorio
  criterion="entropy", # Criterio para la selección del umbral de decisión
  max_features="sqrt",
  max_depth=30,
  min_samples_split=2,
  min_samples_leaf=1
  )

train_sizes_10 = [0.2, 0.4, 0.6, 0.8, 0.9, 1]

train_size_abs_10, train_scores_10, test_scores_10 = learning_curve(
    modeloRF, X_resampled, y_resampled, train_sizes=train_sizes_10, scoring='recall',
    cv=10, n_jobs=-1
    #n_jobs=4, pre_dispatch='2*n_jobs'
)

end = pd.Timestamp.now()
print(f"Duración búsqueda: {end-start}")

for train_size, cv_train_scores, cv_test_scores in zip(
    train_size_abs_10, train_scores_10, test_scores_10
):
    print(f"{train_size} samples were used to train the model")
    print(f"The average train accuracy is {cv_train_scores.mean():.2f}")
    print(f"The average test accuracy is {cv_test_scores.mean():.2f}")

# Suponiendo que 'train_size_abs_10' tiene los tamaños absolutos del conjunto de entrenamiento
total_data_size = max(train_size_abs_10)  # El tamaño total del conjunto de datos

# Convertir los tamaños de entrenamiento a porcentaje
train_size_pct_10 = (train_size_abs_10 / total_data_size) * 100

# Calcular los promedios y desviaciones estándar (ya lo tienes)
train_mean_10 = np.mean(train_scores_10, axis=1)
train_std_10 = np.std(train_scores_10, axis=1)
test_mean_10 = np.mean(test_scores_10, axis=1)
test_std_10 = np.std(test_scores_10, axis=1)

# Graficar la curva de aprendizaje
plt.plot(train_size_pct_10, train_mean_10, color='#FF7B00', marker='o', markersize=5, label='Training Recall')
plt.fill_between(train_size_pct_10, train_mean_10 + train_std_10, train_mean_10 - train_std_10, alpha=0.15, color='#FF7B00')

plt.plot(train_size_pct_10, test_mean_10, color='#8B4513', marker='+', markersize=5, linestyle='--', label='Validation Recall')
plt.fill_between(train_size_pct_10, test_mean_10 + test_std_10, test_mean_10 - test_std_10, alpha=0.15, color='#8B4513')

# Personalización del gráfico
plt.title('Learning Curve R0S, combinación 90%')
plt.xlabel('Training Data Size (%)')  # Cambiar la etiqueta del eje x
plt.ylabel('Model Recall')
plt.ylim(0, 1)
plt.grid()
plt.legend(loc='lower right')

# Mostrar el gráfico
plt.show()
# Out:
# Duración búsqueda: 0 days 00:01:22.486830
# 8411 samples were used to train the model
# The average train accuracy is 1.00
# The average test accuracy is 0.46
# 16822 samples were used to train the model
# The average train accuracy is 0.99
# The average test accuracy is 0.62
# 25233 samples were used to train the model
# The average train accuracy is 0.98
# The average test accuracy is 0.75
# 33644 samples were used to train the model
# The average train accuracy is 1.00
# The average test accuracy is 0.95
# 37849 samples were used to train the model
# The average train accuracy is 1.00
# The average test accuracy is 0.97
# 42055 samples were used to train the model
# The average train accuracy is 1.00
# The average test accuracy is 0.99

# %%
# ENTRENAR MEJORES MODELOS

# DF CON TRAIN_SIZE=0.90

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, train_size=0.90, random_state=42)

#Medir tiempo de ejecución
start = pd.Timestamp.now()

# Crear el mejor modelo
best_rf_90 = RandomForestClassifier(
    n_estimators=100,               # Número de árboles en el bosque
    criterion="entropy",          # Criterio para la división de nodos ('entropy' para la ganancia de información)
    max_features="sqrt",          # Número de características a considerar en cada división ('sqrt' para la raíz cuadrada del número total de características)}
    max_depth=30,
    min_samples_split=2,
    min_samples_leaf=1,
    n_jobs = -1,
    random_state = 42
)

# Ajustar modelo
fit_90 = best_rf_90.fit(X_train, y_train)

#Medir tiempo de ejecución
end = pd.Timestamp.now()
print(f"Duración búsqueda: {end-start}")

# Matriz de confusión para model_grid.best_params_
y_pred = fit_90.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# Crear la visualización de la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['PAGO', 'NO PAGO'])

# Graficar la matriz de confusión con un título
fig, ax = plt.subplots(figsize=(8, 6))  # Configurar el tamaño del gráfico
disp.plot(cmap="Blues", ax=ax)  # Asociar la visualización con los ejes del gráfico
ax.set_title("Matriz de Confusión - Mejor Modelo Random Forest ROS (90%)", fontsize=16)

# Mostrar el gráfico
plt.show()
# Out:
# Duración búsqueda: 0 days 00:00:02.078442

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de las métricas para las dos bases de datos
metrics = ["Recall", "Precision", "F1-SCORE", "AUC-ROC", "AUPRC"]
db1_scores = [1, 0.9999, 0.9999, 0.9999, 0.9999]  # Ejemplo de métricas para la base de datos 1
db2_scores = [0.9181, 0.8711, 0.8740, 0.95, 0.9673]  # Ejemplo de métricas para la base de datos 2

# Configuración del gráfico
x = np.arange(len(metrics))  # Posiciones de las métricas
width = 0.35  # Ancho de las barras

fig, ax = plt.subplots(figsize=(10, 6))

# Colores en gama de azules y cafés
color_db1 = "#6C91BF"  # Azul
color_db2 = "#A5673F"  # Café

# Barras para las métricas de cada base de datos
bars1 = ax.bar(x - width/2, db1_scores, width, label="Base de Datos 1", color=color_db1)
bars2 = ax.bar(x + width/2, db2_scores, width, label="Base de Datos 2", color=color_db2)

# Etiquetas y formato
ax.set_xlabel("Métricas", fontsize=12)
ax.set_ylabel("Valores", fontsize=12)
ax.set_title("Comparación de Métricas entre Bases de Datos R0S (ts=0.75)", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=11)
ax.legend(fontsize=11)
ax.set_ylim(0, 1)  # Asumiendo que los valores están entre 0 y 1

# Añadir valores sobre las barras
for bars in [bars1, bars2]:
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.02, f"{yval:.2f}", ha="center", fontsize=10)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de las métricas para las dos bases de datos
metrics = ["Recall", "Precision", "F1-SCORE", "AUC-ROC", "AUPRC"]
db1_scores = [1, 0.9999, 0.9999, 1, 1]  # Ejemplo de métricas para la base de datos 1
db2_scores = [0.9269, 0.8766, 0.9011, 0.9550, 0.9616]  # Ejemplo de métricas para la base de datos 2

# Configuración del gráfico
x = np.arange(len(metrics))  # Posiciones de las métricas
width = 0.35  # Ancho de las barras

fig, ax = plt.subplots(figsize=(10, 6))

# Colores en gama de azules y cafés
color_db1 = "#6C91BF"  # Azul
color_db2 = "#A5673F"  # Café

# Barras para las métricas de cada base de datos
bars1 = ax.bar(x - width/2, db1_scores, width, label="Base de Datos 1", color=color_db1)
bars2 = ax.bar(x + width/2, db2_scores, width, label="Base de Datos 2", color=color_db2)

# Etiquetas y formato
ax.set_xlabel("Métricas", fontsize=12)
ax.set_ylabel("Valores", fontsize=12)
ax.set_title("Comparación de Métricas entre Bases de Datos R0S (ts=0.80)", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=11)
ax.legend(fontsize=11)
ax.set_ylim(0, 1)  # Asumiendo que los valores están entre 0 y 1

# Añadir valores sobre las barras
for bars in [bars1, bars2]:
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.02, f"{yval:.2f}", ha="center", fontsize=10)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de las métricas para las dos bases de datos
metrics = ["Recall", "Precision", "F1-SCORE", "AUC-ROC", "AUPRC"]
db1_scores = [1, 0.9999, 0.9999, 0.9999, 0.9999]  # Ejemplo de métricas para la base de datos 1
db2_scores = [0.9399, 0.8829, 0.9105, 0.9624, 0.9681]  # Ejemplo de métricas para la base de datos 2

# Configuración del gráfico
x = np.arange(len(metrics))  # Posiciones de las métricas
width = 0.35  # Ancho de las barras

fig, ax = plt.subplots(figsize=(10, 6))

# Colores en gama de azules y cafés
color_db1 = "#6C91BF"  # Azul
color_db2 = "#A5673F"  # Café

# Barras para las métricas de cada base de datos
bars1 = ax.bar(x - width/2, db1_scores, width, label="Base de Datos 1", color=color_db1)
bars2 = ax.bar(x + width/2, db2_scores, width, label="Base de Datos 2", color=color_db2)

# Etiquetas y formato
ax.set_xlabel("Métricas", fontsize=12)
ax.set_ylabel("Valores", fontsize=12)
ax.set_title("Comparación de Métricas entre Bases de Datos R0S (ts=0.90)", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=11)
ax.legend(fontsize=11)
ax.set_ylim(0, 1)  # Asumiendo que los valores están entre 0 y 1

# Añadir valores sobre las barras
for bars in [bars1, bars2]:
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.02, f"{yval:.2f}", ha="center", fontsize=10)

# Mostrar el gráfico
plt.tight_layout()
plt.show()
