# %% [markdown]
# # **CARGAR DATOS E IMPORTAR BIBLIOTECAS NECESARIAS**

# %%
# BIBLIOTECAS NECESARIAS

# Bibliotecas para operaciones numéricas y manejo de datos
import numpy as np  # Operaciones numéricas
import pandas as pd  # Manejo de datos en formato tabular

# División del conjunto de datos y validación cruzada
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
# Modelos de clasificación
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler

# Importar todo el módulo de métricas
import sklearn.metrics

# Métricas de evaluación y reportes
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    PrecisionRecallDisplay,
    roc_curve, auc,
    classification_report,
    accuracy_score, precision_score, recall_score, f1_score
)

from collections import Counter
from sklearn.datasets import make_classification

# Bibliotecas para gráficos
import matplotlib.pyplot as plt  # Gráficos básicos
import seaborn as sns  # Gráficos estadísticos, con menos código que matplotlib
import plotly.express as px  # Gráficos interactivos con interfaz sencilla y de alto nivel
import plotly.graph_objects as go  # Gráficos interactivos con interfaz más detallada y de bajo nivel

# Herramientas para iteradores
import itertools  # Herramientas funcionales para crear y utilizar iteradores

# Herramientas para preprocesamiento de datos y evaluación de modelos
from sklearn.preprocessing import StandardScaler  # Escalado de características para normalizar datos
from sklearn.model_selection import learning_curve  # Generación de curvas de aprendizaje para evaluar el rendimiento del modelo
from sklearn.model_selection import validation_curve  # Generación de curvas de validación para evaluar el rendimiento del modelo

# %%
# Cargar el dataset desde un archivo CSV
credit_card = pd.read_csv('C:\\Users\\mmene\\OneDrive\\Escritorio\\RESULTADOS PROYECTO\\DATA\\default_of_credit_card_clients.csv')

# %%
credit_card.head(10)
# Out:
#        X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...     X15     X16     X17  \
# 0   20000   2   2   1  24   2   2  -1  -1   -2  ...       0       0       0
# 1  120000   2   2   2  26  -1   2   0   0    0  ...    3272    3455    3261
# 2   90000   2   2   2  34   0   0   0   0    0  ...   14331   14948   15549
# 3   50000   2   2   1  37   0   0   0   0    0  ...   28314   28959   29547
# 4   50000   1   2   1  57  -1   0  -1   0    0  ...   20940   19146   19131
# 5   50000   1   1   2  37   0   0   0   0    0  ...   19394   19619   20024
# 6  500000   1   1   2  29   0   0   0   0    0  ...  542653  483003  473944
# 7  100000   2   2   2  23   0  -1  -1   0    0  ...     221    -159     567
# 8  140000   2   3   1  28   0   0   2   0    0  ...   12211   11793    3719
# 9   20000   1   3   2  35  -2  -2  -2  -2   -1  ...       0   13007   13912
#
#      X18    X19    X20    X21    X22    X23  Y
# 0      0    689      0      0      0      0  1
# 1      0   1000   1000   1000      0   2000  1
# 2   1518   1500   1000   1000   1000   5000  0
# 3   2000   2019   1200   1100   1069   1000  0
# 4   2000  36681  10000   9000    689    679  0
# 5   2500   1815    657   1000   1000    800  0
# 6  55000  40000  38000  20239  13750  13770  0
# 7    380    601      0    581   1687   1542  0
# 8   3329      0    432   1000   1000   1000  0
# 9      0      0      0  13007   1122      0  0
#
# [10 rows x 24 columns]

# %% [markdown]
# # **PREPROCESAMIENTO**

# %%
# Paso 1: Separar características (X) y la columna objetivo (y)
X = credit_card.drop(['Y'], axis=1)  # Eliminar la columna 'Y'
y = credit_card['Y']  # Conservar la columna 'Y'

# Paso 2: Crear un objeto StandardScaler
scaler = StandardScaler()

# Paso 3: Ajustar el escalador a las características y transformarlas
scaled = scaler.fit_transform(X)

# Paso 4: Convertir X_scaled de vuelta a un DataFrame
X_scaled = pd.DataFrame(scaled, columns=X.columns)

# Paso 5: Reunir X_scaled con la columna 'Class'
credit_card_scaled = pd.concat([X_scaled, y.reset_index(drop=True)], axis=1)

# Paso 6: Mostrar las primeras filas del DataFrame transformado
print(credit_card_scaled.head())
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -1.136720  0.810161  0.185828 -1.057295 -1.246020  1.794564  1.782348
# 1 -0.365981  0.810161  0.185828  0.858557 -1.029047 -0.874991  1.782348
# 2 -0.597202  0.810161  0.185828  0.858557 -0.161156  0.014861  0.111736
# 3 -0.905498  0.810161  0.185828 -1.057295  0.164303  0.014861  0.111736
# 4 -0.905498 -1.234323  0.185828 -1.057295  2.334029 -0.874991  0.111736
#
#          X8        X9       X10  ...       X15       X16       X17       X18  \
# 0 -0.696663 -0.666599 -1.530046  ... -0.672497 -0.663059 -0.652724 -0.341942
# 1  0.138865  0.188746  0.234917  ... -0.621636 -0.606229 -0.597966 -0.341942
# 2  0.138865  0.188746  0.234917  ... -0.449730 -0.417188 -0.391630 -0.250292
# 3  0.138865  0.188746  0.234917  ... -0.232373 -0.186729 -0.156579 -0.221191
# 4 -0.696663  0.188746  0.234917  ... -0.346997 -0.348137 -0.331482 -0.221191
#
#         X19       X20       X21       X22       X23  Y
# 0 -0.227086 -0.296801 -0.308063 -0.314136 -0.293382  1
# 1 -0.213588 -0.240005 -0.244230 -0.314136 -0.180878  1
# 2 -0.191887 -0.240005 -0.244230 -0.248683 -0.012122  0
# 3 -0.169361 -0.228645 -0.237846 -0.244166 -0.237130  0
# 4  1.335034  0.271165  0.266434 -0.269039 -0.255187  0
#
# [5 rows x 24 columns]

# %%
ros = RandomUnderSampler(random_state=42)

X_resampled, y_resampled = ros.fit_resample(X_scaled,y)

credit_card_resampled = pd.DataFrame(X_resampled, columns=X.columns)
credit_card_resampled['Y'] = y_resampled

print(credit_card_resampled.head())
print(credit_card_resampled['Y'].value_counts())
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 7510   1.637943  0.810161  1.451114  0.858557 -0.486615 -0.874991 -0.723570
# 15325  0.558907  0.810161  0.185828 -1.057295 -0.052670 -1.764843 -1.558876
# 18666 -0.905498  0.810161 -1.079457  0.858557 -1.354506 -0.874991 -0.723570
# 7494   1.252573 -1.234323 -1.079457  0.858557 -0.378129  0.014861  0.111736
# 1239  -0.674276  0.810161  0.185828 -1.057295 -0.052670 -0.874991 -0.723570
#
#              X8        X9       X10  ...       X15       X16       X17  \
# 7510  -0.696663 -0.666599 -0.647565  ... -0.499224 -0.457733 -0.423013
# 15325 -1.532192 -1.521944 -1.530046  ... -0.584858 -0.620589 -0.583425
# 18666 -1.532192 -1.521944 -1.530046  ... -0.672497 -0.663059 -0.652724
# 7494   0.138865  0.188746  0.234917  ...  1.526307  1.189575  1.383139
# 1239  -0.696663 -0.666599 -0.647565  ... -0.666342 -0.656545 -0.646075
#
#             X18       X19       X20       X21       X22       X23  Y
# 7510   0.215928  0.404151  0.339435  0.489402  0.585717  0.722584  0
# 15325  0.103328 -0.043973  0.023418 -0.142927 -0.044010 -0.015385  0
# 18666 -0.341942 -0.256990 -0.296801 -0.308063 -0.314136 -0.293382  0
# 7494  -0.009876 -0.052003  0.015580 -0.052731  0.386215 -0.040248  0
# 1239   0.249497  0.326462 -0.274310 -0.282785 -0.314136 -0.271106  0
#
# [5 rows x 24 columns]
# Y
# 0    6636
# 1    6636
# Name: count, dtype: int64

# %%
from matplotlib.lines import Line2D  # Para crear la leyenda personalizada
# VISUALIZACIÓN 3D DE LA DISTRIBUCIÓN DE CLASES EN DATOS DE TRANSACCIONES CON RUS

# Crear la figura y el gráfico 3D
fig = plt.figure(figsize=(12, 9))  # Tamaño de la figura
ax = fig.add_subplot(111, projection='3d')  # Crear un eje 3D en la figura

# Usar el colormap 'viridis' para asignar colores a las clases
cmap = plt.cm.viridis  # Cargar el colormap 'viridis', que asigna colores a las clases

# Definir colores específicos para cada clase (clase 0 y clase 1)
# Usamos el color más oscuro para la clase 0 y el amarillo para la clase 1
colors = [cmap(0), cmap(0.999999)]  # Primer color para clase 0, segundo color (amarillo) para clase 1

# Crear el gráfico de dispersión 3D, asignando colores según las clases
scatter = ax.scatter(
    X_resampled.iloc[:, 5],  # Coordenada X usando la columna 14 de X_scaled
    X_resampled.iloc[:, 4],  # Coordenada Y usando la columna 17 de X_scaled
    X_resampled.iloc[:, 11],  # Coordenada Z usando la columna 10 de X_scaled
    c=y_resampled,  # Asignar colores a los puntos basados en la variable 'y' (las clases)
    cmap=plt.cm.colors.ListedColormap(colors),  # Aplicar el colormap personalizado
    alpha=0.6  # Ajustar la transparencia de los puntos
)

# Etiquetar los ejes con los nombres de las variables correspondientes
ax.set_xlabel('X6', fontsize=12, labelpad=10)
ax.set_zlabel('X12', fontsize=12, labelpad=10)
ax.set_ylabel('X5', fontsize=12, labelpad=10)

# Agregar un título claro y centrado al gráfico
plt.title(
    'GRÁFICO DE DISPERSIÓN DE CLASES\nPOR INCUMPLIMIENTO DE PAGO CON RANDOM UNDERSAMPLING (BD2)',  # Título con salto de línea
    fontsize=14,  # Tamaño de la fuente
    fontweight='bold',  # Poner el título en negrita
    color='#1C325B',  # Color azul oscuro
    loc='center',  # Centrar el título
    y=1  # Ajustar la posición vertical del título
)

# Ajustar la perspectiva del gráfico 3D para mejorar la visualización
ax.view_init(elev=20, azim=-60)  # Elevación y ángulo de azimut del gráfico 3D

# Crear los objetos de la leyenda con los colores definidos previamente para cada clase
handles = [
    Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[0], markersize=10),  # Clase 0 (no fraudulenta)
    Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[1], markersize=10)   # Clase 1 (fraudulenta)
]

etiq =  {0: f"No incumplió el pago", 1: f"Incumplió el pago"}

# Asignar las etiquetas correspondientes a las clases para la leyenda
labels = [etiq[0], etiq[1]]  # 'etiq' debe contener las etiquetas de las clases (asegurarse de que esté definida)

# Colocar la leyenda en la parte superior central del gráfico
ax.legend(
    handles=handles,  # Usar los objetos creados para la leyenda
    labels=labels,  # Etiquetas de las clases
    loc='upper center',  # Ubicación de la leyenda
    fontsize=12,  # Tamaño de la fuente de la leyenda
    title_fontsize=14,  # Tamaño de la fuente del título de la leyenda
    bbox_to_anchor=(0.9, 0.9)  # Posicionar la leyenda fuera del gráfico, en la parte derecha
)

# Mostrar el gráfico generado
plt.show()

# %%
# Calcula el recuento de las clases de transacción (no fraudulenta y fraudulenta) y los ordena por índice
class_counts = credit_card_resampled['Y'].value_counts().sort_index()

# Extrae los valores (recuentos) de las clases
valores = class_counts.values

# Define etiquetas para las clases (0: no fraudulenta, 1: fraudulenta)
# Estas etiquetas se utilizarán en el gráfico para representar cada segmento
etiq =  {0: f"pagó", 1: f"impago"}

# Crea un gráfico de pastel con Plotly Express
# 'values' representa el tamaño de cada segmento, y 'names' proporciona las etiquetas para cada segmento
fig = px.pie(credit_card_resampled, values=valores, names=etiq,
             title='<b>DISTRIBUCIÓN DE CLASES</b>',
             color_discrete_sequence=['#522258', '#FFE31A'],
             )

# Ajusta el tamaño del texto del porcentaje en el gráfico para mejorar la visibilidad
fig.update_traces(textinfo='percent', textfont_size=15)

# Centra el título y coloca la leyenda debajo del gráfico
fig.update_layout(
    title_x=0.5,  # Centra el título
    title_y=0.90,  # Ajusta la posición vertical del título
    showlegend=True,  # Activa la leyenda
    legend_orientation="h",  # Pone la leyenda horizontal
    legend_y=-0.05,  # Coloca la leyenda debajo del gráfico
    legend_x=0.2
)

# Muestra el gráfico
fig.show()

# %% [markdown]
# # MODELO ENSAMBLADO: **RANDOM FOREST + RUS**

# %%
# 'HOLDOUT METHOD' para evaluar el rendimiento de un modelo de aprendizaje automático
# Este método divide el conjunto de datos en entrenamiento y prueba con diferentes tamaños de entrenamiento
# para evaluar cómo el rendimiento del modelo varía con el tamaño del conjunto de entrenamiento.

# Definir los diferentes tamaños para el conjunto de entrenamiento
train_sizes = [0.75,0.80,0.90]

# Crear una lista para almacenar los resultados de los diferentes conjuntos de entrenamiento y prueba
split_results = []

# Para cada tamaño de entrenamiento en train_sizes
for splits in train_sizes:
  # Se divide los datos X e y en conjuntos de entrenamiento y prueba con el tamaño especificado
  X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, train_size=splits, random_state=42)
  split_results.append((X_train, X_test, y_train, y_test))

# Mostrar las dimensiones de los conjuntos de entrenamiento y prueba para cada tamaño de entrenamiento
for i, (X_train, X_test, y_train, y_test) in enumerate(split_results):
  print(f"\033[1mConjunto con train_size={train_sizes[i]}\033[0m")
  print(f"Dimensión total es: {credit_card_resampled.shape}")
  print(f"X_train dimensión: {X_train.shape}, X_test dimensión: {X_test.shape}")
  print(f"y_train dimensión: {y_train.shape}, y_test dimensión: {y_test.shape}")
  print()
# Out:
# Conjunto con train_size=0.75
# Dimensión total es: (13272, 24)
# X_train dimensión: (9954, 23), X_test dimensión: (3318, 23)
# y_train dimensión: (9954,), y_test dimensión: (3318,)
#
# Conjunto con train_size=0.8
# Dimensión total es: (13272, 24)
# X_train dimensión: (10617, 23), X_test dimensión: (2655, 23)
# y_train dimensión: (10617,), y_test dimensión: (2655,)
#
# Conjunto con train_size=0.9
# Dimensión total es: (13272, 24)
# X_train dimensión: (11944, 23), X_test dimensión: (1328, 23)
# y_train dimensión: (11944,), y_test dimensión: (1328,)

# %%
# MODELO RANDOM FOREST

# Lista para almacenar el resultado del modelo para cada conjunto de entrenamiento/prueba
models_split_results = []

# Iterar sobre los conjuntos generados
for i, (X_train, X_test, y_train, y_test) in enumerate(split_results):

  # Definir las métricas de evaluación
  scores = ["precision", "recall", "roc_auc", "f1", "average_precision"]

  # Mostrar información sobre el conjunto actual
  print(f"\033[1mConjunto con train_size={train_sizes[i]}:\033[0m")

  # Crear el modelo RANDOM FOREST
  modeloRF = RandomForestClassifier(
      n_jobs = -1, # Utilizar todos los núcleos disponibles para acelerar el entrenamiento
      random_state = 42 # Semilla para la reproducibilidad de los resultados
      )

  # Definir los parámetros para GridSearchCV
  grid_search = {
      "n_estimators": [10,12,14,16,18,20,50,100,200], # Número de árboles en el bosque aleatorio
      "criterion": ["gini", "entropy"], # Criterio para la selección del umbral de
      "max_features": ["sqrt","log2"], # Número máximo de características a considerar
      "max_depth": [10,20,30], # Profundidad máxima de cada
      "min_samples_split": [2,5,10], # Número mínimo de muestras requeridas para dividir un nodo interno
      "min_samples_leaf": [1,2,4] # Número mínimo de muestras requeridas en cada hoja
      }

  # Medir tiempo de ejecución
  start = pd.Timestamp.now()

  # Configuración de GridSearchCV
  grid = GridSearchCV(
      modeloRF,
      grid_search,
      cv=3, # Número de particiones en la validación cruzada
      refit=False, # No volver a entrenar el mejor modelo encontrado en toda la búsqueda
      scoring=scores, # Métricas de evaluación a usar
      verbose = 3, # Mostrar información adicional durante la búsqueda
      return_train_score=True # Devolver los resultados de entrenamiento
      )

  # Ejecutar GridSearchCV para encontrar el mejor modelo
  model_grid = grid.fit(X_train, y_train)

  # Medir tiempo de ejecución de GridSearchCV
  end = pd.Timestamp.now()
  print(f"Duración búsqueda: {end-start}")

  # Almacenar los resultados en la list 'models_split_results'
  models_split_results.append(model_grid.cv_results_)

  # Guardar modelos en un DataFrame
modelos_GSCV1= pd.DataFrame(models_split_results)

model_75 = models_split_results[0]
model_80 = models_split_results[1]
model_90 = models_split_results[2]

#75
# Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
ajuste_modelo_75 = []

# Recorre cada índice 'i' basado en la longitud de los tiempos medios de ajuste ('mean_fit_time')
for i in range(len(model_75['mean_fit_time'])):
  # Crea un diccionario 'execution' para la ejecución actual, extrayendo el valor correspondiente al índice 'i' de cada clave en 'resultados_modelo_75'
  execution = {key: value[i] for key, value in model_75.items()}
  # Añade el diccionario de resultados de la ejecución actual a la lista 'ajuste_modelo_80'
  ajuste_modelo_75.append(execution)

# Convierte la lista de diccionarios 'ajuste_modelo_75' en un DataFrame de pandas para facilitar su manipulación y análisis
modelos_75 = pd.DataFrame(ajuste_modelo_75)
# Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
modelos_75.to_excel('C:\\Users\\mmene\\OneDrive\\Escritorio\\RESULTADOS PROYECTO\\MODELOS\\Random Forest\\default_of_credit_card_clients (BD2)\\modelos_75_RUS.xlsx')

#80
# Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
ajuste_modelo_80 = []

# Recorre cada índice 'i' basado en la longitud de los tiempos medios de ajuste ('mean_fit_time')
for i in range(len(model_80['mean_fit_time'])):
  # Crea un diccionario 'execution' para la ejecución actual, extrayendo el valor correspondiente al índice 'i' de cada clave en 'resultados_modelo_75'
  execution = {key: value[i] for key, value in model_80.items()}
  # Añade el diccionario de resultados de la ejecución actual a la lista 'ajuste_modelo_80'
  ajuste_modelo_80.append(execution)

# Convierte la lista de diccionarios 'ajuste_modelo_80' en un DataFrame de pandas para facilitar su manipulación y análisis
modelos_80 = pd.DataFrame(ajuste_modelo_80)
# Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
modelos_80.to_excel('C:\\Users\\mmene\\OneDrive\\Escritorio\\RESULTADOS PROYECTO\\MODELOS\\Random Forest\\default_of_credit_card_clients (BD2)\\modelos_80_RUS.xlsx')


#90
# Crear una lista de diccionarios, donde cada diccionario corresponde a una ejecución
ajuste_modelo_90 = []

# Recorre cada índice 'i' basado en la longitud de los tiempos medios de ajuste ('mean_fit_time')
for i in range(len(model_90['mean_fit_time'])):
  # Crea un diccionario 'execution' para la ejecución actual, extrayendo el valor correspondiente al índice 'i' de cada clave en 'resultados_modelo_75'
  execution = {key: value[i] for key, value in model_90.items()}
  # Añade el diccionario de resultados de la ejecución actual a la lista 'ajuste_modelo_80'
  ajuste_modelo_90.append(execution)

# Convierte la lista de diccionarios 'ajuste_modelo_90' en un DataFrame de pandas para facilitar su manipulación y análisis
modelos_90 = pd.DataFrame(ajuste_modelo_90)
# Guarda el DataFrame resultante en un archivo Excel, permitiendo almacenar los resultados de manera estructurada
modelos_90.to_excel('C:\\Users\\mmene\\OneDrive\\Escritorio\\RESULTADOS PROYECTO\\MODELOS\\Random Forest\\default_of_credit_card_clients (BD2)\\modelos_80_RUS.xlsx')
# Out:
# Conjunto con train_size=0.75:
# Fitting 3 folds for each of 972 candidates, totalling 2916 fits
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10; average_precision: (train=0.912, test=0.757) f1: (train=0.796, test=0.669) precision: (train=0.868, test=0.712) recall: (train=0.735, test=0.632) roc_auc: (train=0.903, test=0.751) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10; average_precision: (train=0.902, test=0.777) f1: (train=0.786, test=0.684) precision: (train=0.861, test=0.746) recall: (train=0.723, test=0.631) roc_auc: (train=0.886, test=0.777) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10; average_precision: (train=0.904, test=0.772) f1: (train=0.797, test=0.679) precision: (train=0.847, test=0.731) recall: (train=0.753, test=0.634) roc_auc: (train=0.894, test=0.763) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=12; average_precision: (train=0.915, test=0.756) f1: (train=0.801, test=0.675) precision: (train=0.874, test=0.721) recall: (train=0.740, test=0.634) roc_auc: (train=0.906, test=0.752) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=12; average_precision: (train=0.906, test=0.781) f1: (train=0.790, test=0.685) precision: (train=0.865, test=0.752) recall: (train=0.728, test=0.629) roc_auc: (train=0.891, test=0.779) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=12; average_precision: (train=0.906, test=0.772) f1: (train=0.798, test=0.680) precision: (train=0.853, test=0.734) recall: (train=0.749, test=0.632) roc_auc: (train=0.896, test=0.765) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=14; average_precision: (train=0.918, test=0.759) f1: (train=0.805, test=0.673) precision: (train=0.880, test=0.720) recall: (train=0.741, test=0.632) roc_auc: (train=0.909, test=0.754) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=14; average_precision: (train=0.909, test=0.780) f1: (train=0.790, test=0.687) precision: (train=0.868, test=0.754) recall: (train=0.725, test=0.631) roc_auc: (train=0.894, test=0.779) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=14; average_precision: (train=0.909, test=0.773) f1: (train=0.800, test=0.686) precision: (train=0.856, test=0.739) recall: (train=0.751, test=0.639) roc_auc: (train=0.898, test=0.767) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=16; average_precision: (train=0.920, test=0.761) f1: (train=0.803, test=0.673) precision: (train=0.881, test=0.722) recall: (train=0.738, test=0.630) roc_auc: (train=0.911, test=0.757) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=16; average_precision: (train=0.911, test=0.781) f1: (train=0.792, test=0.691) precision: (train=0.871, test=0.758) recall: (train=0.727, test=0.635) roc_auc: (train=0.897, test=0.780) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=16; average_precision: (train=0.910, test=0.776) f1: (train=0.798, test=0.685) precision: (train=0.855, test=0.742) recall: (train=0.749, test=0.636) roc_auc: (train=0.899, test=0.769) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=18; average_precision: (train=0.920, test=0.761) f1: (train=0.804, test=0.675) precision: (train=0.882, test=0.723) recall: (train=0.739, test=0.633) roc_auc: (train=0.911, test=0.758) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=18; average_precision: (train=0.912, test=0.782) f1: (train=0.793, test=0.694) precision: (train=0.869, test=0.760) recall: (train=0.729, test=0.640) roc_auc: (train=0.899, test=0.781) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=18; average_precision: (train=0.912, test=0.779) f1: (train=0.801, test=0.682) precision: (train=0.862, test=0.739) recall: (train=0.749, test=0.632) roc_auc: (train=0.901, test=0.770) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20; average_precision: (train=0.920, test=0.763) f1: (train=0.803, test=0.673) precision: (train=0.883, test=0.726) recall: (train=0.736, test=0.627) roc_auc: (train=0.912, test=0.759) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20; average_precision: (train=0.911, test=0.783) f1: (train=0.791, test=0.693) precision: (train=0.868, test=0.761) recall: (train=0.727, test=0.636) roc_auc: (train=0.898, test=0.782) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20; average_precision: (train=0.913, test=0.781) f1: (train=0.804, test=0.680) precision: (train=0.865, test=0.736) recall: (train=0.751, test=0.632) roc_auc: (train=0.903, test=0.771) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; average_precision: (train=0.920, test=0.767) f1: (train=0.801, test=0.672) precision: (train=0.880, test=0.730) recall: (train=0.735, test=0.622) roc_auc: (train=0.911, test=0.763) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; average_precision: (train=0.915, test=0.786) f1: (train=0.790, test=0.694) precision: (train=0.874, test=0.763) recall: (train=0.721, test=0.637) roc_auc: (train=0.901, test=0.783) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; average_precision: (train=0.918, test=0.784) f1: (train=0.797, test=0.677) precision: (train=0.869, test=0.745) recall: (train=0.737, test=0.621) roc_auc: (train=0.907, test=0.774) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; average_precision: (train=0.922, test=0.768) f1: (train=0.801, test=0.671) precision: (train=0.885, test=0.735) recall: (train=0.732, test=0.617) roc_auc: (train=0.913, test=0.763) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; average_precision: (train=0.917, test=0.786) f1: (train=0.793, test=0.694) precision: (train=0.878, test=0.763) recall: (train=0.724, test=0.637) roc_auc: (train=0.904, test=0.783) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; average_precision: (train=0.919, test=0.788) f1: (train=0.800, test=0.681) precision: (train=0.872, test=0.753) recall: (train=0.740, test=0.622) roc_auc: (train=0.910, test=0.776) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; average_precision: (train=0.924, test=0.771) f1: (train=0.801, test=0.671) precision: (train=0.880, test=0.733) recall: (train=0.734, test=0.618) roc_auc: (train=0.915, test=0.763) total time=   0.4s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; average_precision: (train=0.918, test=0.787) f1: (train=0.794, test=0.696) precision: (train=0.879, test=0.764) recall: (train=0.723, test=0.638) roc_auc: (train=0.906, test=0.783) total time=   0.5s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; average_precision: (train=0.921, test=0.790) f1: (train=0.800, test=0.686) precision: (train=0.869, test=0.755) recall: (train=0.742, test=0.628) roc_auc: (train=0.912, test=0.777) total time=   0.5s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10; average_precision: (train=0.903, test=0.758) f1: (train=0.785, test=0.676) precision: (train=0.858, test=0.731) recall: (train=0.724, test=0.629) roc_auc: (train=0.893, test=0.755) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10; average_precision: (train=0.897, test=0.775) f1: (train=0.778, test=0.680) precision: (train=0.846, test=0.742) recall: (train=0.719, test=0.628) roc_auc: (train=0.884, test=0.772) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10; average_precision: (train=0.898, test=0.770) f1: (train=0.796, test=0.674) precision: (train=0.840, test=0.730) recall: (train=0.756, test=0.627) roc_auc: (train=0.888, test=0.760) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=12; average_precision: (train=0.906, test=0.764) f1: (train=0.789, test=0.670) precision: (train=0.862, test=0.729) recall: (train=0.727, test=0.620) roc_auc: (train=0.898, test=0.758) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=12; average_precision: (train=0.901, test=0.777) f1: (train=0.779, test=0.681) precision: (train=0.855, test=0.745) recall: (train=0.716, test=0.627) roc_auc: (train=0.889, test=0.775) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=12; average_precision: (train=0.900, test=0.771) f1: (train=0.794, test=0.673) precision: (train=0.841, test=0.727) recall: (train=0.751, test=0.626) roc_auc: (train=0.890, test=0.762) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=14; average_precision: (train=0.909, test=0.764) f1: (train=0.789, test=0.673) precision: (train=0.866, test=0.730) recall: (train=0.725, test=0.624) roc_auc: (train=0.899, test=0.758) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=14; average_precision: (train=0.901, test=0.778) f1: (train=0.778, test=0.688) precision: (train=0.856, test=0.751) recall: (train=0.713, test=0.635) roc_auc: (train=0.889, test=0.776) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=14; average_precision: (train=0.901, test=0.773) f1: (train=0.795, test=0.679) precision: (train=0.841, test=0.733) recall: (train=0.754, test=0.633) roc_auc: (train=0.891, test=0.765) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=16; average_precision: (train=0.911, test=0.763) f1: (train=0.791, test=0.673) precision: (train=0.868, test=0.735) recall: (train=0.727, test=0.621) roc_auc: (train=0.902, test=0.758) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=16; average_precision: (train=0.903, test=0.777) f1: (train=0.782, test=0.685) precision: (train=0.861, test=0.753) recall: (train=0.717, test=0.628) roc_auc: (train=0.890, test=0.776) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=16; average_precision: (train=0.903, test=0.778) f1: (train=0.798, test=0.679) precision: (train=0.844, test=0.735) recall: (train=0.756, test=0.631) roc_auc: (train=0.893, test=0.767) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=18; average_precision: (train=0.911, test=0.763) f1: (train=0.795, test=0.670) precision: (train=0.868, test=0.731) recall: (train=0.734, test=0.618) roc_auc: (train=0.902, test=0.758) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=18; average_precision: (train=0.904, test=0.779) f1: (train=0.784, test=0.688) precision: (train=0.865, test=0.747) recall: (train=0.716, test=0.638) roc_auc: (train=0.892, test=0.778) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=18; average_precision: (train=0.903, test=0.779) f1: (train=0.793, test=0.674) precision: (train=0.846, test=0.737) recall: (train=0.747, test=0.620) roc_auc: (train=0.893, test=0.767) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=20; average_precision: (train=0.911, test=0.764) f1: (train=0.794, test=0.668) precision: (train=0.870, test=0.731) recall: (train=0.730, test=0.615) roc_auc: (train=0.902, test=0.759) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=20; average_precision: (train=0.905, test=0.781) f1: (train=0.784, test=0.689) precision: (train=0.863, test=0.756) recall: (train=0.719, test=0.633) roc_auc: (train=0.892, test=0.779) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=20; average_precision: (train=0.904, test=0.782) f1: (train=0.795, test=0.676) precision: (train=0.849, test=0.738) recall: (train=0.748, test=0.623) roc_auc: (train=0.895, test=0.768) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; average_precision: (train=0.915, test=0.769) f1: (train=0.793, test=0.673) precision: (train=0.868, test=0.730) recall: (train=0.730, test=0.624) roc_auc: (train=0.906, test=0.763) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; average_precision: (train=0.910, test=0.786) f1: (train=0.782, test=0.687) precision: (train=0.866, test=0.755) recall: (train=0.713, test=0.629) roc_auc: (train=0.898, test=0.782) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; average_precision: (train=0.912, test=0.787) f1: (train=0.797, test=0.676) precision: (train=0.861, test=0.742) recall: (train=0.741, test=0.620) roc_auc: (train=0.902, test=0.773) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; average_precision: (train=0.916, test=0.772) f1: (train=0.794, test=0.674) precision: (train=0.873, test=0.733) recall: (train=0.729, test=0.623) roc_auc: (train=0.907, test=0.765) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; average_precision: (train=0.910, test=0.788) f1: (train=0.785, test=0.690) precision: (train=0.867, test=0.761) recall: (train=0.717, test=0.631) roc_auc: (train=0.898, test=0.784) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; average_precision: (train=0.912, test=0.788) f1: (train=0.794, test=0.681) precision: (train=0.861, test=0.753) recall: (train=0.737, test=0.621) roc_auc: (train=0.902, test=0.775) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; average_precision: (train=0.917, test=0.772) f1: (train=0.794, test=0.676) precision: (train=0.870, test=0.733) recall: (train=0.730, test=0.627) roc_auc: (train=0.909, test=0.765) total time=   0.4s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; average_precision: (train=0.911, test=0.788) f1: (train=0.787, test=0.690) precision: (train=0.869, test=0.758) recall: (train=0.720, test=0.632) roc_auc: (train=0.899, test=0.783) total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; average_precision: (train=0.912, test=0.790) f1: (train=0.791, test=0.683) precision: (train=0.856, test=0.756) recall: (train=0.734, test=0.623) roc_auc: (train=0.904, test=0.777) total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=10; average_precision: (train=0.893, test=0.757) f1: (train=0.773, test=0.672) precision: (train=0.849, test=0.733) recall: (train=0.710, test=0.621) roc_auc: (train=0.882, test=0.756) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=10; average_precision: (train=0.888, test=0.776) f1: (train=0.771, test=0.687) precision: (train=0.835, test=0.747) recall: (train=0.716, test=0.636) roc_auc: (train=0.873, test=0.774) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=10; average_precision: (train=0.888, test=0.779) f1: (train=0.779, test=0.682) precision: (train=0.827, test=0.734) recall: (train=0.737, test=0.636) roc_auc: (train=0.877, test=0.767) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=12; average_precision: (train=0.895, test=0.761) f1: (train=0.776, test=0.669) precision: (train=0.851, test=0.725) recall: (train=0.714, test=0.621) roc_auc: (train=0.886, test=0.758) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=12; average_precision: (train=0.891, test=0.776) f1: (train=0.772, test=0.683) precision: (train=0.840, test=0.742) recall: (train=0.713, test=0.633) roc_auc: (train=0.877, test=0.775) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=12; average_precision: (train=0.891, test=0.782) f1: (train=0.781, test=0.681) precision: (train=0.830, test=0.737) recall: (train=0.737, test=0.633) roc_auc: (train=0.879, test=0.769) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=14; average_precision: (train=0.898, test=0.761) f1: (train=0.776, test=0.666) precision: (train=0.853, test=0.731) recall: (train=0.712, test=0.612) roc_auc: (train=0.889, test=0.758) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=14; average_precision: (train=0.894, test=0.777) f1: (train=0.776, test=0.687) precision: (train=0.845, test=0.742) recall: (train=0.717, test=0.640) roc_auc: (train=0.880, test=0.777) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=14; average_precision: (train=0.892, test=0.784) f1: (train=0.782, test=0.682) precision: (train=0.832, test=0.741) recall: (train=0.737, test=0.631) roc_auc: (train=0.880, test=0.771) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=16; average_precision: (train=0.899, test=0.764) f1: (train=0.777, test=0.670) precision: (train=0.853, test=0.733) recall: (train=0.714, test=0.617) roc_auc: (train=0.890, test=0.760) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=16; average_precision: (train=0.896, test=0.777) f1: (train=0.778, test=0.688) precision: (train=0.847, test=0.743) recall: (train=0.719, test=0.640) roc_auc: (train=0.882, test=0.777) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=16; average_precision: (train=0.894, test=0.786) f1: (train=0.782, test=0.682) precision: (train=0.836, test=0.743) recall: (train=0.735, test=0.631) roc_auc: (train=0.882, test=0.772) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=18; average_precision: (train=0.899, test=0.764) f1: (train=0.776, test=0.671) precision: (train=0.853, test=0.732) recall: (train=0.712, test=0.618) roc_auc: (train=0.890, test=0.760) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=18; average_precision: (train=0.896, test=0.781) f1: (train=0.779, test=0.688) precision: (train=0.848, test=0.746) recall: (train=0.720, test=0.638) roc_auc: (train=0.883, test=0.780) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=18; average_precision: (train=0.895, test=0.786) f1: (train=0.784, test=0.673) precision: (train=0.839, test=0.737) recall: (train=0.735, test=0.620) roc_auc: (train=0.883, test=0.772) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=20; average_precision: (train=0.900, test=0.763) f1: (train=0.782, test=0.671) precision: (train=0.857, test=0.732) recall: (train=0.719, test=0.620) roc_auc: (train=0.892, test=0.760) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=20; average_precision: (train=0.897, test=0.783) f1: (train=0.782, test=0.690) precision: (train=0.851, test=0.749) recall: (train=0.723, test=0.640) roc_auc: (train=0.884, test=0.781) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=20; average_precision: (train=0.895, test=0.786) f1: (train=0.783, test=0.677) precision: (train=0.839, test=0.742) recall: (train=0.735, test=0.622) roc_auc: (train=0.884, test=0.771) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; average_precision: (train=0.904, test=0.767) f1: (train=0.778, test=0.671) precision: (train=0.853, test=0.731) recall: (train=0.715, test=0.620) roc_auc: (train=0.894, test=0.763) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; average_precision: (train=0.899, test=0.788) f1: (train=0.774, test=0.694) precision: (train=0.852, test=0.761) recall: (train=0.708, test=0.637) roc_auc: (train=0.885, test=0.784) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; average_precision: (train=0.897, test=0.788) f1: (train=0.780, test=0.677) precision: (train=0.842, test=0.746) recall: (train=0.726, test=0.619) roc_auc: (train=0.887, test=0.774) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; average_precision: (train=0.903, test=0.767) f1: (train=0.778, test=0.668) precision: (train=0.855, test=0.730) recall: (train=0.714, test=0.615) roc_auc: (train=0.894, test=0.763) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; average_precision: (train=0.899, test=0.786) f1: (train=0.776, test=0.689) precision: (train=0.854, test=0.757) recall: (train=0.710, test=0.631) roc_auc: (train=0.886, test=0.783) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; average_precision: (train=0.900, test=0.790) f1: (train=0.782, test=0.677) precision: (train=0.845, test=0.751) recall: (train=0.727, test=0.617) roc_auc: (train=0.891, test=0.778) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; average_precision: (train=0.905, test=0.770) f1: (train=0.776, test=0.670) precision: (train=0.855, test=0.734) recall: (train=0.710, test=0.616) roc_auc: (train=0.896, test=0.764) total time=   0.4s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; average_precision: (train=0.901, test=0.788) f1: (train=0.778, test=0.691) precision: (train=0.855, test=0.760) recall: (train=0.713, test=0.634) roc_auc: (train=0.888, test=0.785) total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; average_precision: (train=0.901, test=0.792) f1: (train=0.781, test=0.680) precision: (train=0.848, test=0.752) recall: (train=0.724, test=0.620) roc_auc: (train=0.891, test=0.779) total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10; average_precision: (train=0.905, test=0.769) f1: (train=0.794, test=0.670) precision: (train=0.869, test=0.721) recall: (train=0.731, test=0.625) roc_auc: (train=0.892, test=0.759) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10; average_precision: (train=0.895, test=0.779) f1: (train=0.772, test=0.683) precision: (train=0.849, test=0.754) recall: (train=0.708, test=0.623) roc_auc: (train=0.877, test=0.775) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10; average_precision: (train=0.898, test=0.772) f1: (train=0.794, test=0.675) precision: (train=0.846, test=0.728) recall: (train=0.749, test=0.629) roc_auc: (train=0.887, test=0.762) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=12; average_precision: (train=0.907, test=0.772) f1: (train=0.794, test=0.673) precision: (train=0.872, test=0.730) recall: (train=0.729, test=0.623) roc_auc: (train=0.896, test=0.761) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=12; average_precision: (train=0.899, test=0.782) f1: (train=0.777, test=0.689) precision: (train=0.859, test=0.767) recall: (train=0.710, test=0.626) roc_auc: (train=0.883, test=0.777) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=12; average_precision: (train=0.901, test=0.775) f1: (train=0.792, test=0.679) precision: (train=0.846, test=0.735) recall: (train=0.744, test=0.631) roc_auc: (train=0.890, test=0.764) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=14; average_precision: (train=0.910, test=0.769) f1: (train=0.797, test=0.674) precision: (train=0.872, test=0.726) recall: (train=0.734, test=0.629) roc_auc: (train=0.899, test=0.761) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=14; average_precision: (train=0.902, test=0.783) f1: (train=0.778, test=0.690) precision: (train=0.861, test=0.764) recall: (train=0.710, test=0.629) roc_auc: (train=0.887, test=0.779) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=14; average_precision: (train=0.904, test=0.777) f1: (train=0.792, test=0.683) precision: (train=0.848, test=0.736) recall: (train=0.743, test=0.637) roc_auc: (train=0.892, test=0.768) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=16; average_precision: (train=0.910, test=0.770) f1: (train=0.795, test=0.676) precision: (train=0.870, test=0.730) recall: (train=0.732, test=0.629) roc_auc: (train=0.900, test=0.762) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=16; average_precision: (train=0.903, test=0.783) f1: (train=0.778, test=0.689) precision: (train=0.862, test=0.762) recall: (train=0.709, test=0.628) roc_auc: (train=0.889, test=0.779) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=16; average_precision: (train=0.904, test=0.780) f1: (train=0.792, test=0.685) precision: (train=0.850, test=0.745) recall: (train=0.741, test=0.634) roc_auc: (train=0.893, test=0.770) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=18; average_precision: (train=0.911, test=0.771) f1: (train=0.796, test=0.677) precision: (train=0.871, test=0.732) recall: (train=0.732, test=0.630) roc_auc: (train=0.901, test=0.763) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=18; average_precision: (train=0.904, test=0.785) f1: (train=0.780, test=0.688) precision: (train=0.862, test=0.762) recall: (train=0.712, test=0.628) roc_auc: (train=0.891, test=0.780) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=18; average_precision: (train=0.905, test=0.782) f1: (train=0.790, test=0.686) precision: (train=0.852, test=0.745) recall: (train=0.737, test=0.635) roc_auc: (train=0.895, test=0.773) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=20; average_precision: (train=0.911, test=0.771) f1: (train=0.795, test=0.674) precision: (train=0.873, test=0.732) recall: (train=0.729, test=0.626) roc_auc: (train=0.901, test=0.763) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=20; average_precision: (train=0.905, test=0.785) f1: (train=0.779, test=0.688) precision: (train=0.864, test=0.764) recall: (train=0.709, test=0.625) roc_auc: (train=0.891, test=0.780) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=20; average_precision: (train=0.906, test=0.784) f1: (train=0.792, test=0.689) precision: (train=0.853, test=0.750) recall: (train=0.739, test=0.637) roc_auc: (train=0.896, test=0.773) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; average_precision: (train=0.915, test=0.771) f1: (train=0.795, test=0.674) precision: (train=0.870, test=0.735) recall: (train=0.731, test=0.623) roc_auc: (train=0.906, test=0.765) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; average_precision: (train=0.909, test=0.787) f1: (train=0.780, test=0.692) precision: (train=0.862, test=0.761) recall: (train=0.713, test=0.634) roc_auc: (train=0.895, test=0.783) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; average_precision: (train=0.911, test=0.788) f1: (train=0.792, test=0.686) precision: (train=0.858, test=0.753) recall: (train=0.735, test=0.630) roc_auc: (train=0.901, test=0.775) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; average_precision: (train=0.916, test=0.773) f1: (train=0.794, test=0.669) precision: (train=0.873, test=0.732) recall: (train=0.727, test=0.617) roc_auc: (train=0.907, test=0.765) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; average_precision: (train=0.910, test=0.789) f1: (train=0.784, test=0.691) precision: (train=0.866, test=0.756) recall: (train=0.716, test=0.635) roc_auc: (train=0.897, test=0.782) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; average_precision: (train=0.912, test=0.791) f1: (train=0.790, test=0.685) precision: (train=0.859, test=0.755) recall: (train=0.731, test=0.628) roc_auc: (train=0.902, test=0.778) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; average_precision: (train=0.917, test=0.773) f1: (train=0.792, test=0.671) precision: (train=0.870, test=0.733) recall: (train=0.727, test=0.620) roc_auc: (train=0.908, test=0.765) total time=   0.4s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; average_precision: (train=0.912, test=0.788) f1: (train=0.788, test=0.690) precision: (train=0.868, test=0.756) recall: (train=0.722, test=0.635) roc_auc: (train=0.899, test=0.783) total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; average_precision: (train=0.912, test=0.791) f1: (train=0.791, test=0.684) precision: (train=0.857, test=0.756) recall: (train=0.734, test=0.625) roc_auc: (train=0.903, test=0.779) total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; average_precision: (train=0.906, test=0.755) f1: (train=0.783, test=0.672) precision: (train=0.858, test=0.720) recall: (train=0.720, test=0.630) roc_auc: (train=0.894, test=0.755) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; average_precision: (train=0.892, test=0.781) f1: (train=0.774, test=0.685) precision: (train=0.850, test=0.753) recall: (train=0.711, test=0.628) roc_auc: (train=0.875, test=0.779) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; average_precision: (train=0.895, test=0.771) f1: (train=0.788, test=0.673) precision: (train=0.836, test=0.723) recall: (train=0.746, test=0.629) roc_auc: (train=0.882, test=0.759) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=12; average_precision: (train=0.908, test=0.756) f1: (train=0.787, test=0.675) precision: (train=0.866, test=0.733) recall: (train=0.721, test=0.625) roc_auc: (train=0.899, test=0.756) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=12; average_precision: (train=0.896, test=0.782) f1: (train=0.773, test=0.683) precision: (train=0.855, test=0.758) recall: (train=0.705, test=0.622) roc_auc: (train=0.880, test=0.780) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=12; average_precision: (train=0.898, test=0.773) f1: (train=0.788, test=0.675) precision: (train=0.838, test=0.727) recall: (train=0.744, test=0.629) roc_auc: (train=0.885, test=0.760) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=14; average_precision: (train=0.910, test=0.757) f1: (train=0.787, test=0.672) precision: (train=0.862, test=0.724) recall: (train=0.725, test=0.627) roc_auc: (train=0.901, test=0.758) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=14; average_precision: (train=0.899, test=0.783) f1: (train=0.771, test=0.684) precision: (train=0.856, test=0.760) recall: (train=0.701, test=0.622) roc_auc: (train=0.883, test=0.780) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=14; average_precision: (train=0.900, test=0.777) f1: (train=0.789, test=0.677) precision: (train=0.843, test=0.735) recall: (train=0.742, test=0.628) roc_auc: (train=0.887, test=0.765) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=16; average_precision: (train=0.910, test=0.760) f1: (train=0.789, test=0.671) precision: (train=0.864, test=0.726) recall: (train=0.726, test=0.623) roc_auc: (train=0.901, test=0.759) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=16; average_precision: (train=0.901, test=0.781) f1: (train=0.776, test=0.682) precision: (train=0.862, test=0.755) recall: (train=0.705, test=0.622) roc_auc: (train=0.886, test=0.780) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=16; average_precision: (train=0.901, test=0.779) f1: (train=0.788, test=0.675) precision: (train=0.845, test=0.738) recall: (train=0.739, test=0.622) roc_auc: (train=0.888, test=0.767) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=18; average_precision: (train=0.910, test=0.762) f1: (train=0.793, test=0.678) precision: (train=0.868, test=0.731) recall: (train=0.729, test=0.632) roc_auc: (train=0.902, test=0.761) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=18; average_precision: (train=0.902, test=0.783) f1: (train=0.777, test=0.686) precision: (train=0.861, test=0.759) recall: (train=0.708, test=0.626) roc_auc: (train=0.887, test=0.781) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=18; average_precision: (train=0.902, test=0.780) f1: (train=0.787, test=0.678) precision: (train=0.844, test=0.737) recall: (train=0.737, test=0.627) roc_auc: (train=0.890, test=0.769) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=20; average_precision: (train=0.910, test=0.763) f1: (train=0.791, test=0.673) precision: (train=0.867, test=0.726) recall: (train=0.727, test=0.628) roc_auc: (train=0.902, test=0.759) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=20; average_precision: (train=0.902, test=0.784) f1: (train=0.776, test=0.685) precision: (train=0.861, test=0.757) recall: (train=0.707, test=0.626) roc_auc: (train=0.887, test=0.780) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=20; average_precision: (train=0.904, test=0.782) f1: (train=0.793, test=0.680) precision: (train=0.849, test=0.741) recall: (train=0.743, test=0.628) roc_auc: (train=0.892, test=0.770) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; average_precision: (train=0.913, test=0.765) f1: (train=0.789, test=0.676) precision: (train=0.863, test=0.730) recall: (train=0.726, test=0.629) roc_auc: (train=0.903, test=0.762) total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; average_precision: (train=0.906, test=0.786) f1: (train=0.777, test=0.694) precision: (train=0.858, test=0.758) recall: (train=0.710, test=0.639) roc_auc: (train=0.893, test=0.783) total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; average_precision: (train=0.908, test=0.790) f1: (train=0.790, test=0.685) precision: (train=0.852, test=0.751) recall: (train=0.736, test=0.630) roc_auc: (train=0.896, test=0.776) total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; average_precision: (train=0.914, test=0.767) f1: (train=0.789, test=0.671) precision: (train=0.867, test=0.729) recall: (train=0.723, test=0.621) roc_auc: (train=0.904, test=0.763) total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; average_precision: (train=0.907, test=0.787) f1: (train=0.781, test=0.689) precision: (train=0.863, test=0.757) recall: (train=0.713, test=0.631) roc_auc: (train=0.893, test=0.783) total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; average_precision: (train=0.910, test=0.790) f1: (train=0.788, test=0.682) precision: (train=0.853, test=0.754) recall: (train=0.732, test=0.623) roc_auc: (train=0.900, test=0.777) total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; average_precision: (train=0.915, test=0.770) f1: (train=0.788, test=0.673) precision: (train=0.865, test=0.730) recall: (train=0.724, test=0.624) roc_auc: (train=0.906, test=0.765) total time=   0.4s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; average_precision: (train=0.908, test=0.787) f1: (train=0.781, test=0.694) precision: (train=0.863, test=0.761) recall: (train=0.713, test=0.638) roc_auc: (train=0.894, test=0.784) total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; average_precision: (train=0.911, test=0.790) f1: (train=0.787, test=0.679) precision: (train=0.853, test=0.751) recall: (train=0.731, test=0.620) roc_auc: (train=0.901, test=0.778) total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=10; average_precision: (train=0.890, test=0.769) f1: (train=0.764, test=0.671) precision: (train=0.844, test=0.729) recall: (train=0.697, test=0.623) roc_auc: (train=0.877, test=0.764) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=10; average_precision: (train=0.889, test=0.778) f1: (train=0.770, test=0.687) precision: (train=0.847, test=0.750) recall: (train=0.707, test=0.635) roc_auc: (train=0.874, test=0.778) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=10; average_precision: (train=0.887, test=0.776) f1: (train=0.778, test=0.682) precision: (train=0.829, test=0.738) recall: (train=0.733, test=0.634) roc_auc: (train=0.876, test=0.764) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=12; average_precision: (train=0.892, test=0.771) f1: (train=0.767, test=0.676) precision: (train=0.845, test=0.734) recall: (train=0.703, test=0.627) roc_auc: (train=0.881, test=0.765) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=12; average_precision: (train=0.893, test=0.778) f1: (train=0.772, test=0.685) precision: (train=0.849, test=0.749) recall: (train=0.709, test=0.632) roc_auc: (train=0.878, test=0.777) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=12; average_precision: (train=0.890, test=0.779) f1: (train=0.779, test=0.678) precision: (train=0.831, test=0.736) recall: (train=0.733, test=0.629) roc_auc: (train=0.879, test=0.767) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=14; average_precision: (train=0.894, test=0.767) f1: (train=0.771, test=0.678) precision: (train=0.846, test=0.735) recall: (train=0.709, test=0.629) roc_auc: (train=0.883, test=0.765) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=14; average_precision: (train=0.895, test=0.780) f1: (train=0.772, test=0.690) precision: (train=0.850, test=0.752) recall: (train=0.708, test=0.638) roc_auc: (train=0.881, test=0.779) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=14; average_precision: (train=0.893, test=0.782) f1: (train=0.778, test=0.677) precision: (train=0.834, test=0.741) recall: (train=0.729, test=0.624) roc_auc: (train=0.882, test=0.768) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=16; average_precision: (train=0.895, test=0.769) f1: (train=0.774, test=0.675) precision: (train=0.852, test=0.734) recall: (train=0.710, test=0.626) roc_auc: (train=0.884, test=0.766) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=16; average_precision: (train=0.895, test=0.781) f1: (train=0.775, test=0.693) precision: (train=0.849, test=0.756) recall: (train=0.713, test=0.640) roc_auc: (train=0.881, test=0.781) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=16; average_precision: (train=0.895, test=0.784) f1: (train=0.780, test=0.676) precision: (train=0.838, test=0.742) recall: (train=0.731, test=0.620) roc_auc: (train=0.883, test=0.769) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=18; average_precision: (train=0.895, test=0.769) f1: (train=0.771, test=0.674) precision: (train=0.848, test=0.731) recall: (train=0.707, test=0.626) roc_auc: (train=0.885, test=0.766) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=18; average_precision: (train=0.895, test=0.782) f1: (train=0.775, test=0.693) precision: (train=0.848, test=0.754) recall: (train=0.713, test=0.641) roc_auc: (train=0.881, test=0.781) total time=   0.0s
# ...
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=12; average_precision: (train=0.966, test=0.769) f1: (train=0.895, test=0.683) precision: (train=0.900, test=0.714) recall: (train=0.890, test=0.654) roc_auc: (train=0.967, test=0.762) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=14; average_precision: (train=0.970, test=0.768) f1: (train=0.905, test=0.677) precision: (train=0.904, test=0.713) recall: (train=0.905, test=0.644) roc_auc: (train=0.971, test=0.759) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=14; average_precision: (train=0.969, test=0.770) f1: (train=0.903, test=0.690) precision: (train=0.909, test=0.719) recall: (train=0.897, test=0.664) roc_auc: (train=0.970, test=0.761) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=14; average_precision: (train=0.968, test=0.774) f1: (train=0.901, test=0.686) precision: (train=0.906, test=0.714) recall: (train=0.896, test=0.661) roc_auc: (train=0.970, test=0.766) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=16; average_precision: (train=0.971, test=0.772) f1: (train=0.910, test=0.682) precision: (train=0.906, test=0.724) recall: (train=0.914, test=0.644) roc_auc: (train=0.972, test=0.762) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=16; average_precision: (train=0.970, test=0.771) f1: (train=0.904, test=0.686) precision: (train=0.911, test=0.719) recall: (train=0.898, test=0.656) roc_auc: (train=0.971, test=0.763) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=16; average_precision: (train=0.970, test=0.774) f1: (train=0.905, test=0.689) precision: (train=0.909, test=0.717) recall: (train=0.900, test=0.663) roc_auc: (train=0.971, test=0.766) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=18; average_precision: (train=0.972, test=0.772) f1: (train=0.910, test=0.682) precision: (train=0.907, test=0.726) recall: (train=0.914, test=0.642) roc_auc: (train=0.973, test=0.762) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=18; average_precision: (train=0.971, test=0.772) f1: (train=0.905, test=0.686) precision: (train=0.911, test=0.718) recall: (train=0.898, test=0.657) roc_auc: (train=0.973, test=0.763) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=18; average_precision: (train=0.971, test=0.777) f1: (train=0.908, test=0.689) precision: (train=0.911, test=0.719) recall: (train=0.905, test=0.661) roc_auc: (train=0.972, test=0.767) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=20; average_precision: (train=0.973, test=0.771) f1: (train=0.910, test=0.679) precision: (train=0.908, test=0.725) recall: (train=0.912, test=0.638) roc_auc: (train=0.975, test=0.761) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=20; average_precision: (train=0.972, test=0.773) f1: (train=0.907, test=0.684) precision: (train=0.912, test=0.717) recall: (train=0.902, test=0.654) roc_auc: (train=0.974, test=0.765) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=20; average_precision: (train=0.972, test=0.781) f1: (train=0.911, test=0.690) precision: (train=0.910, test=0.723) recall: (train=0.911, test=0.659) roc_auc: (train=0.973, test=0.770) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; average_precision: (train=0.979, test=0.779) f1: (train=0.931, test=0.680) precision: (train=0.923, test=0.733) recall: (train=0.939, test=0.634) roc_auc: (train=0.980, test=0.767) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; average_precision: (train=0.978, test=0.781) f1: (train=0.920, test=0.691) precision: (train=0.920, test=0.729) recall: (train=0.920, test=0.657) roc_auc: (train=0.979, test=0.772) total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; average_precision: (train=0.977, test=0.787) f1: (train=0.919, test=0.691) precision: (train=0.917, test=0.730) recall: (train=0.922, test=0.657) roc_auc: (train=0.978, test=0.779) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; average_precision: (train=0.980, test=0.778) f1: (train=0.932, test=0.680) precision: (train=0.922, test=0.732) recall: (train=0.942, test=0.635) roc_auc: (train=0.982, test=0.768) total time=   0.3s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; average_precision: (train=0.979, test=0.784) f1: (train=0.926, test=0.693) precision: (train=0.922, test=0.733) recall: (train=0.931, test=0.656) roc_auc: (train=0.981, test=0.777) total time=   0.4s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; average_precision: (train=0.978, test=0.788) f1: (train=0.925, test=0.691) precision: (train=0.921, test=0.735) recall: (train=0.930, test=0.652) roc_auc: (train=0.980, test=0.780) total time=   0.3s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; average_precision: (train=0.981, test=0.778) f1: (train=0.932, test=0.681) precision: (train=0.921, test=0.735) recall: (train=0.943, test=0.634) roc_auc: (train=0.982, test=0.769) total time=   0.7s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; average_precision: (train=0.980, test=0.786) f1: (train=0.930, test=0.695) precision: (train=0.926, test=0.740) recall: (train=0.934, test=0.655) roc_auc: (train=0.981, test=0.779) total time=   0.7s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; average_precision: (train=0.979, test=0.789) f1: (train=0.929, test=0.692) precision: (train=0.922, test=0.737) recall: (train=0.937, test=0.651) roc_auc: (train=0.981, test=0.780) total time=   0.7s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=10; average_precision: (train=0.961, test=0.756) f1: (train=0.888, test=0.672) precision: (train=0.892, test=0.704) recall: (train=0.884, test=0.644) roc_auc: (train=0.962, test=0.751) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=10; average_precision: (train=0.958, test=0.765) f1: (train=0.882, test=0.687) precision: (train=0.894, test=0.708) recall: (train=0.871, test=0.668) roc_auc: (train=0.958, test=0.759) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=10; average_precision: (train=0.958, test=0.771) f1: (train=0.888, test=0.685) precision: (train=0.894, test=0.719) recall: (train=0.883, test=0.653) roc_auc: (train=0.959, test=0.759) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=12; average_precision: (train=0.963, test=0.758) f1: (train=0.895, test=0.676) precision: (train=0.897, test=0.713) recall: (train=0.892, test=0.643) roc_auc: (train=0.965, test=0.753) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=12; average_precision: (train=0.960, test=0.768) f1: (train=0.886, test=0.685) precision: (train=0.897, test=0.709) recall: (train=0.875, test=0.663) roc_auc: (train=0.961, test=0.762) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=12; average_precision: (train=0.960, test=0.774) f1: (train=0.892, test=0.686) precision: (train=0.896, test=0.720) recall: (train=0.888, test=0.655) roc_auc: (train=0.962, test=0.761) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=14; average_precision: (train=0.965, test=0.761) f1: (train=0.899, test=0.674) precision: (train=0.901, test=0.715) recall: (train=0.896, test=0.637) roc_auc: (train=0.967, test=0.756) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=14; average_precision: (train=0.963, test=0.768) f1: (train=0.890, test=0.685) precision: (train=0.899, test=0.711) recall: (train=0.882, test=0.660) roc_auc: (train=0.964, test=0.765) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=14; average_precision: (train=0.963, test=0.775) f1: (train=0.897, test=0.686) precision: (train=0.899, test=0.721) recall: (train=0.895, test=0.655) roc_auc: (train=0.965, test=0.764) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=16; average_precision: (train=0.967, test=0.763) f1: (train=0.901, test=0.675) precision: (train=0.902, test=0.715) recall: (train=0.901, test=0.640) roc_auc: (train=0.968, test=0.757) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=16; average_precision: (train=0.965, test=0.767) f1: (train=0.894, test=0.684) precision: (train=0.901, test=0.710) recall: (train=0.888, test=0.659) roc_auc: (train=0.966, test=0.765) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=16; average_precision: (train=0.965, test=0.777) f1: (train=0.901, test=0.686) precision: (train=0.902, test=0.721) recall: (train=0.899, test=0.653) roc_auc: (train=0.966, test=0.766) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=18; average_precision: (train=0.968, test=0.764) f1: (train=0.900, test=0.677) precision: (train=0.902, test=0.720) recall: (train=0.898, test=0.639) roc_auc: (train=0.969, test=0.758) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=18; average_precision: (train=0.966, test=0.769) f1: (train=0.896, test=0.682) precision: (train=0.904, test=0.715) recall: (train=0.889, test=0.652) roc_auc: (train=0.968, test=0.766) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=18; average_precision: (train=0.966, test=0.776) f1: (train=0.898, test=0.687) precision: (train=0.902, test=0.727) recall: (train=0.894, test=0.652) roc_auc: (train=0.967, test=0.765) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=20; average_precision: (train=0.968, test=0.765) f1: (train=0.901, test=0.677) precision: (train=0.904, test=0.721) recall: (train=0.898, test=0.638) roc_auc: (train=0.970, test=0.760) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=20; average_precision: (train=0.967, test=0.771) f1: (train=0.897, test=0.683) precision: (train=0.905, test=0.712) recall: (train=0.889, test=0.657) roc_auc: (train=0.968, test=0.768) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=20; average_precision: (train=0.967, test=0.778) f1: (train=0.902, test=0.685) precision: (train=0.904, test=0.726) recall: (train=0.900, test=0.648) roc_auc: (train=0.968, test=0.767) total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; average_precision: (train=0.974, test=0.777) f1: (train=0.919, test=0.680) precision: (train=0.914, test=0.732) recall: (train=0.924, test=0.635) roc_auc: (train=0.975, test=0.768) total time=   0.1s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; average_precision: (train=0.972, test=0.783) f1: (train=0.909, test=0.687) precision: (train=0.912, test=0.730) recall: (train=0.907, test=0.649) roc_auc: (train=0.974, test=0.776) total time=   0.1s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; average_precision: (train=0.970, test=0.786) f1: (train=0.908, test=0.684) precision: (train=0.907, test=0.732) recall: (train=0.910, test=0.642) roc_auc: (train=0.972, test=0.775) total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; average_precision: (train=0.975, test=0.779) f1: (train=0.918, test=0.680) precision: (train=0.912, test=0.731) recall: (train=0.924, test=0.635) roc_auc: (train=0.977, test=0.770) total time=   0.3s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; average_precision: (train=0.974, test=0.785) f1: (train=0.915, test=0.686) precision: (train=0.914, test=0.730) recall: (train=0.916, test=0.647) roc_auc: (train=0.976, test=0.778) total time=   0.3s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; average_precision: (train=0.972, test=0.788) f1: (train=0.912, test=0.690) precision: (train=0.909, test=0.736) recall: (train=0.915, test=0.649) roc_auc: (train=0.974, test=0.778) total time=   0.3s
# [CV 1/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; average_precision: (train=0.976, test=0.780) f1: (train=0.921, test=0.678) precision: (train=0.914, test=0.736) recall: (train=0.929, test=0.628) roc_auc: (train=0.977, test=0.770) total time=   0.7s
# [CV 2/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; average_precision: (train=0.975, test=0.787) f1: (train=0.916, test=0.687) precision: (train=0.915, test=0.731) recall: (train=0.916, test=0.647) roc_auc: (train=0.977, test=0.781) total time=   0.7s
# [CV 3/3] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; average_precision: (train=0.973, test=0.789) f1: (train=0.914, test=0.688) precision: (train=0.912, test=0.735) recall: (train=0.917, test=0.647) roc_auc: (train=0.975, test=0.779) total time=   0.7s
# Duración búsqueda: 0 days 00:13:27.270547
